# %% [markdown]
# # This is StlyeGAN2-ADA-pytorch for black and white images

# %% [markdown]
# ## Generate dataset

# %%
# !python dataset_tool_gray.py --source= source images --dest= ./dataset_floder.zip --transform=center-crop --width=512 --height=512
# Out:
#   0%|                                                  | 0/4432 [00:00<?, ?it/s]{'width': 512, 'height': 512, 'channels': 1}
# 100%|███████████████████████████████████████| 4432/4432 [01:08<00:00, 64.81it/s]

# %% [markdown]
# ### examples

# %%
# !python dataset_tool_gray.py --source=../DCGAN/Knee_GAN/new_images/1/1 --dest=./datasets/0323oiaclassify1.zip --transform=center-crop --width=512 --height=512

# %% [markdown]
# ## Training

# %% [markdown]
# ### --dry run is for check parameters

# %%
# !python train.py --outdir=./outdir --data=dataset_floder.zip --gpus=2 --cfg=auto --kimg =1000 --dry-run
# !python train.py --outdir=./outdir--data= dataset_floder.zip --gpus=N_GPU --cfg=auto

# %% [markdown]
# ### examples

# %%
# !python train.py --outdir=./training-runs --data=./datasets/0323oiaclassify1.zip  --gpus=2 --cfg=auto
# Out:
# Training options:
# {
#   "num_gpus": 2,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "./datasets/GAN_1000.zip",
#     "use_labels": false,
#     "max_size": 1000,
#     "xflip": false,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 3.2768
#   },
#   "total_kimg": 1000,
#   "batch_size": 16,
#   "batch_gpu": 8,
#   "ema_kimg": 5.0,
#   "ema_rampup": 0.05,
#   "ada_target": 0.6,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "run_dir": "./training-runs/00011-GAN_1000-auto2"
# }
#
# Output directory:   ./training-runs/00011-GAN_1000-auto2
# Training data:      ./datasets/GAN_1000.zip
# Training duration:  1000 kimg
# Number of GPUs:     2
# Number of images:   1000
# Image resolution:   512
# Conditional model:  False
# Dataset x-flips:    False
#
# Creating output directory...
# Launching processes...
# Loading training set...
#
# Num images:  1000
# Image shape: [1, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Generator             Parameters  Buffers  Output shape        Datatype
# ---                   ---         ---      ---                 ---
# mapping.fc0           262656      -        [8, 512]            float32
# mapping.fc1           262656      -        [8, 512]            float32
# mapping               -           512      [8, 16, 512]        float32
# synthesis.b4.conv1    2622465     32       [8, 512, 4, 4]      float32
# synthesis.b4.torgb    263169      -        [8, 1, 4, 4]        float32
# synthesis.b4:0        8192        16       [8, 512, 4, 4]      float32
# synthesis.b4:1        -           -        [8, 512, 4, 4]      float32
# synthesis.b8.conv0    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.conv1    2622465     80       [8, 512, 8, 8]      float32
# synthesis.b8.torgb    263169      -        [8, 1, 8, 8]        float32
# synthesis.b8:0        -           16       [8, 512, 8, 8]      float32
# synthesis.b8:1        -           -        [8, 512, 8, 8]      float32
# synthesis.b16.conv0   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.conv1   2622465     272      [8, 512, 16, 16]    float32
# synthesis.b16.torgb   263169      -        [8, 1, 16, 16]      float32
# synthesis.b16:0       -           16       [8, 512, 16, 16]    float32
# synthesis.b16:1       -           -        [8, 512, 16, 16]    float32
# synthesis.b32.conv0   2622465     1040     [8, 512, 32, 32]    float32
# synthesis.b32.conv1   2622465     1040     [8, 512, 32, 32]    float32
# synthesis.b32.torgb   263169      -        [8, 1, 32, 32]      float32
# synthesis.b32:0       -           16       [8, 512, 32, 32]    float32
# synthesis.b32:1       -           -        [8, 512, 32, 32]    float32
# synthesis.b64.conv0   2622465     4112     [8, 512, 64, 64]    float16
# synthesis.b64.conv1   2622465     4112     [8, 512, 64, 64]    float16
# synthesis.b64.torgb   263169      -        [8, 1, 64, 64]      float16
# synthesis.b64:0       -           16       [8, 512, 64, 64]    float16
# synthesis.b64:1       -           -        [8, 512, 64, 64]    float32
# synthesis.b128.conv0  1442561     16400    [8, 256, 128, 128]  float16
# synthesis.b128.conv1  721409      16400    [8, 256, 128, 128]  float16
# synthesis.b128.torgb  131585      -        [8, 1, 128, 128]    float16
# synthesis.b128:0      -           16       [8, 256, 128, 128]  float16
# synthesis.b128:1      -           -        [8, 256, 128, 128]  float32
# synthesis.b256.conv0  426369      65552    [8, 128, 256, 256]  float16
# synthesis.b256.conv1  213249      65552    [8, 128, 256, 256]  float16
# synthesis.b256.torgb  65793       -        [8, 1, 256, 256]    float16
# synthesis.b256:0      -           16       [8, 128, 256, 256]  float16
# synthesis.b256:1      -           -        [8, 128, 256, 256]  float32
# synthesis.b512.conv0  139457      262160   [8, 64, 512, 512]   float16
# synthesis.b512.conv1  69761       262160   [8, 64, 512, 512]   float16
# synthesis.b512.torgb  32897       -        [8, 1, 512, 512]    float16
# synthesis.b512:0      -           16       [8, 64, 512, 512]   float16
# synthesis.b512:1      -           -        [8, 64, 512, 512]   float32
# ---                   ---         ---      ---                 ---
# Total                 28694615    699904   -                   -
#
#
# Discriminator  Parameters  Buffers  Output shape        Datatype
# ---            ---         ---      ---                 ---
# b512.fromrgb   128         16       [8, 64, 512, 512]   float16
# b512.skip      8192        16       [8, 128, 256, 256]  float16
# b512.conv0     36928       16       [8, 64, 512, 512]   float16
# b512.conv1     73856       16       [8, 128, 256, 256]  float16
# b512           -           16       [8, 128, 256, 256]  float16
# b256.skip      32768       16       [8, 256, 128, 128]  float16
# b256.conv0     147584      16       [8, 128, 256, 256]  float16
# b256.conv1     295168      16       [8, 256, 128, 128]  float16
# b256           -           16       [8, 256, 128, 128]  float16
# b128.skip      131072      16       [8, 512, 64, 64]    float16
# b128.conv0     590080      16       [8, 256, 128, 128]  float16
# b128.conv1     1180160     16       [8, 512, 64, 64]    float16
# b128           -           16       [8, 512, 64, 64]    float16
# b64.skip       262144      16       [8, 512, 32, 32]    float16
# b64.conv0      2359808     16       [8, 512, 64, 64]    float16
# b64.conv1      2359808     16       [8, 512, 32, 32]    float16
# b64            -           16       [8, 512, 32, 32]    float16
# b32.skip       262144      16       [8, 512, 16, 16]    float32
# b32.conv0      2359808     16       [8, 512, 32, 32]    float32
# b32.conv1      2359808     16       [8, 512, 16, 16]    float32
# b32            -           16       [8, 512, 16, 16]    float32
# b16.skip       262144      16       [8, 512, 8, 8]      float32
# b16.conv0      2359808     16       [8, 512, 16, 16]    float32
# b16.conv1      2359808     16       [8, 512, 8, 8]      float32
# b16            -           16       [8, 512, 8, 8]      float32
# b8.skip        262144      16       [8, 512, 4, 4]      float32
# b8.conv0       2359808     16       [8, 512, 8, 8]      float32
# b8.conv1       2359808     16       [8, 512, 4, 4]      float32
# b8             -           16       [8, 512, 4, 4]      float32
# b4.mbstd       -           -        [8, 513, 4, 4]      float32
# b4.conv        2364416     16       [8, 512, 4, 4]      float32
# b4.fc          4194816     -        [8, 512]            float32
# b4.out         513         -        [8, 1]              float32
# ---            ---         ---      ---                 ---
# Total          28982721    480      -                   -
#
# Setting up augmentation...
# Distributing across 2 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2021-03-08 18:04:22.313996: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Training for 1000 kimg...
#
# tick 0     kimg 0.0      time 19s          sec/tick 5.6     sec/kimg 353.01  maintenance 12.9   cpumem 4.81   gpumem 10.42  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 383.61116058275707}, "metric": "fid50k_full", "total_time": 342.12948179244995, "total_time_str": "5m 42s", "num_gpus": 2, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1615194616.0246882}
# tick 1     kimg 4.0      time 10m 35s      sec/tick 269.5   sec/kimg 67.36   maintenance 346.7  cpumem 5.00   gpumem 7.67   augment 0.004
# tick 2     kimg 8.0      time 15m 19s      sec/tick 284.2   sec/kimg 71.06   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.010
# tick 3     kimg 12.0     time 19m 57s      sec/tick 277.7   sec/kimg 69.43   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.016
# tick 4     kimg 16.0     time 24m 37s      sec/tick 279.1   sec/kimg 69.78   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.021
# tick 5     kimg 20.0     time 29m 17s      sec/tick 280.1   sec/kimg 70.01   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.021
# tick 6     kimg 24.0     time 33m 58s      sec/tick 281.1   sec/kimg 70.27   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.017
# tick 7     kimg 28.0     time 38m 39s      sec/tick 280.9   sec/kimg 70.23   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.017
# tick 8     kimg 32.0     time 43m 22s      sec/tick 282.5   sec/kimg 70.62   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.013
# tick 9     kimg 36.0     time 48m 05s      sec/tick 282.1   sec/kimg 70.52   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.011
# tick 10    kimg 40.0     time 52m 48s      sec/tick 282.9   sec/kimg 70.73   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.008
# tick 11    kimg 44.0     time 57m 30s      sec/tick 282.1   sec/kimg 70.54   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.003
# tick 12    kimg 48.0     time 1h 02m 13s   sec/tick 282.8   sec/kimg 70.69   maintenance 0.3    cpumem 5.00   gpumem 7.67   augment 0.000
# tick 13    kimg 52.0     time 1h 06m 56s   sec/tick 282.5   sec/kimg 70.63   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 14    kimg 56.0     time 1h 11m 39s   sec/tick 282.7   sec/kimg 70.66   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 15    kimg 60.0     time 1h 16m 22s   sec/tick 282.5   sec/kimg 70.63   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 16    kimg 64.0     time 1h 21m 05s   sec/tick 282.6   sec/kimg 70.65   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 17    kimg 68.0     time 1h 25m 46s   sec/tick 281.5   sec/kimg 70.37   maintenance 0.2    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 18    kimg 72.0     time 1h 30m 29s   sec/tick 282.2   sec/kimg 70.56   maintenance 0.3    cpumem 5.00   gpumem 7.65   augment 0.000
# tick 19    kimg 76.0     time 1h 35m 11s   sec/tick 281.5   sec/kimg 70.38   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 20    kimg 80.0     time 1h 39m 53s   sec/tick 282.1   sec/kimg 70.54   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 21    kimg 84.0     time 1h 44m 35s   sec/tick 281.7   sec/kimg 70.43   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 22    kimg 88.0     time 1h 49m 17s   sec/tick 281.3   sec/kimg 70.34   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 23    kimg 92.0     time 1h 53m 59s   sec/tick 281.7   sec/kimg 70.43   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 24    kimg 96.0     time 1h 58m 41s   sec/tick 282.1   sec/kimg 70.52   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 25    kimg 100.0    time 2h 03m 22s   sec/tick 280.9   sec/kimg 70.24   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 26    kimg 104.0    time 2h 08m 05s   sec/tick 282.0   sec/kimg 70.49   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 27    kimg 108.0    time 2h 12m 46s   sec/tick 281.0   sec/kimg 70.25   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 28    kimg 112.0    time 2h 17m 28s   sec/tick 281.8   sec/kimg 70.45   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 29    kimg 116.0    time 2h 22m 10s   sec/tick 281.5   sec/kimg 70.37   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 30    kimg 120.0    time 2h 26m 52s   sec/tick 281.5   sec/kimg 70.38   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 31    kimg 124.0    time 2h 31m 34s   sec/tick 281.8   sec/kimg 70.45   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 32    kimg 128.0    time 2h 36m 16s   sec/tick 281.9   sec/kimg 70.49   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 33    kimg 132.0    time 2h 40m 58s   sec/tick 281.3   sec/kimg 70.33   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 34    kimg 136.0    time 2h 45m 40s   sec/tick 282.0   sec/kimg 70.50   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 35    kimg 140.0    time 2h 50m 21s   sec/tick 281.4   sec/kimg 70.34   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 36    kimg 144.0    time 2h 55m 04s   sec/tick 282.3   sec/kimg 70.57   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 37    kimg 148.0    time 2h 59m 46s   sec/tick 282.0   sec/kimg 70.49   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 38    kimg 152.0    time 3h 04m 28s   sec/tick 281.7   sec/kimg 70.43   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 39    kimg 156.0    time 3h 09m 11s   sec/tick 282.0   sec/kimg 70.50   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 40    kimg 160.0    time 3h 13m 53s   sec/tick 282.1   sec/kimg 70.54   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 41    kimg 164.0    time 3h 18m 34s   sec/tick 281.2   sec/kimg 70.30   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 42    kimg 168.0    time 3h 23m 17s   sec/tick 282.3   sec/kimg 70.58   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 43    kimg 172.0    time 3h 27m 59s   sec/tick 281.5   sec/kimg 70.37   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 44    kimg 176.0    time 3h 32m 41s   sec/tick 282.4   sec/kimg 70.60   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 45    kimg 180.0    time 3h 37m 24s   sec/tick 282.3   sec/kimg 70.58   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 46    kimg 184.0    time 3h 42m 07s   sec/tick 282.2   sec/kimg 70.56   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 47    kimg 188.0    time 3h 46m 49s   sec/tick 282.5   sec/kimg 70.62   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 48    kimg 192.0    time 3h 51m 32s   sec/tick 282.6   sec/kimg 70.66   maintenance 0.3    cpumem 5.00   gpumem 7.64   augment 0.000
# tick 49    kimg 196.0    time 3h 56m 14s   sec/tick 281.8   sec/kimg 70.44   maintenance 0.3    cpumem 5.00   gpumem 7.65   augment 0.000
# tick 50    kimg 200.0    time 4h 00m 57s   sec/tick 282.6   sec/kimg 70.64   maintenance 0.3    cpumem 5.00   gpumem 7.66   augment 0.001
# Evaluating metrics...
# {"results": {"fid50k_full": 12.70859353176008}, "metric": "fid50k_full", "total_time": 376.62947726249695, "total_time_str": "6m 17s", "num_gpus": 2, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1615209089.291451}
# tick 51    kimg 204.0    time 4h 12m 03s   sec/tick 284.1   sec/kimg 71.01   maintenance 381.3  cpumem 4.95   gpumem 7.66   augment 0.002
# tick 52    kimg 208.0    time 4h 16m 48s   sec/tick 285.1   sec/kimg 71.27   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.003
# tick 53    kimg 212.0    time 4h 21m 33s   sec/tick 284.7   sec/kimg 71.17   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.005
# tick 54    kimg 216.0    time 4h 26m 17s   sec/tick 284.3   sec/kimg 71.06   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.006
# tick 55    kimg 220.0    time 4h 31m 02s   sec/tick 284.3   sec/kimg 71.08   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.008
# tick 56    kimg 224.0    time 4h 35m 47s   sec/tick 284.9   sec/kimg 71.22   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.010
# tick 57    kimg 228.0    time 4h 40m 31s   sec/tick 284.0   sec/kimg 70.99   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.012
# tick 58    kimg 232.0    time 4h 45m 17s   sec/tick 284.8   sec/kimg 71.21   maintenance 0.3    cpumem 4.95   gpumem 7.69   augment 0.015
# tick 59    kimg 236.0    time 4h 50m 01s   sec/tick 283.8   sec/kimg 70.96   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.017
# tick 60    kimg 240.0    time 4h 54m 46s   sec/tick 284.9   sec/kimg 71.23   maintenance 0.3    cpumem 4.95   gpumem 7.68   augment 0.020
# tick 61    kimg 244.0    time 4h 59m 31s   sec/tick 284.4   sec/kimg 71.11   maintenance 0.3    cpumem 4.95   gpumem 7.68   augment 0.022
# tick 62    kimg 248.0    time 5h 04m 15s   sec/tick 284.2   sec/kimg 71.05   maintenance 0.3    cpumem 4.95   gpumem 7.68   augment 0.024
# tick 63    kimg 252.0    time 5h 09m 00s   sec/tick 284.4   sec/kimg 71.10   maintenance 0.3    cpumem 4.95   gpumem 7.68   augment 0.025
# tick 64    kimg 256.0    time 5h 13m 45s   sec/tick 285.0   sec/kimg 71.25   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.026
# tick 65    kimg 260.0    time 5h 18m 30s   sec/tick 284.4   sec/kimg 71.09   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.029
# tick 66    kimg 264.0    time 5h 23m 15s   sec/tick 284.9   sec/kimg 71.22   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.029
# tick 67    kimg 268.0    time 5h 27m 59s   sec/tick 284.1   sec/kimg 71.03   maintenance 0.3    cpumem 4.95   gpumem 7.68   augment 0.030
# tick 68    kimg 272.0    time 5h 32m 45s   sec/tick 284.9   sec/kimg 71.22   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.033
# tick 69    kimg 276.0    time 5h 37m 29s   sec/tick 284.5   sec/kimg 71.12   maintenance 0.3    cpumem 4.95   gpumem 7.67   augment 0.035
# tick 70    kimg 280.0    time 5h 42m 14s   sec/tick 284.1   sec/kimg 71.03   maintenance 0.3    cpumem 4.93   gpumem 7.67   augment 0.035
# tick 71    kimg 284.0    time 5h 46m 58s   sec/tick 284.5   sec/kimg 71.13   maintenance 0.3    cpumem 4.93   gpumem 7.67   augment 0.036
# tick 72    kimg 288.0    time 5h 51m 43s   sec/tick 284.7   sec/kimg 71.17   maintenance 0.3    cpumem 4.93   gpumem 7.67   augment 0.037
# tick 73    kimg 292.0    time 5h 56m 28s   sec/tick 284.0   sec/kimg 70.99   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.039
# tick 74    kimg 296.0    time 6h 01m 13s   sec/tick 284.6   sec/kimg 71.16   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.040
# tick 75    kimg 300.0    time 6h 05m 57s   sec/tick 284.0   sec/kimg 70.99   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.040
# tick 76    kimg 304.0    time 6h 10m 42s   sec/tick 285.1   sec/kimg 71.28   maintenance 0.3    cpumem 4.93   gpumem 7.69   augment 0.039
# tick 77    kimg 308.0    time 6h 15m 27s   sec/tick 284.7   sec/kimg 71.18   maintenance 0.3    cpumem 4.93   gpumem 7.67   augment 0.040
# tick 78    kimg 312.0    time 6h 20m 12s   sec/tick 284.1   sec/kimg 71.02   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.040
# tick 79    kimg 316.0    time 6h 24m 56s   sec/tick 284.1   sec/kimg 71.03   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.040
# tick 80    kimg 320.0    time 6h 29m 41s   sec/tick 284.5   sec/kimg 71.13   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.041
# tick 81    kimg 324.0    time 6h 34m 25s   sec/tick 283.5   sec/kimg 70.87   maintenance 0.3    cpumem 4.93   gpumem 7.67   augment 0.041
# tick 82    kimg 328.0    time 6h 39m 09s   sec/tick 284.3   sec/kimg 71.08   maintenance 0.3    cpumem 4.93   gpumem 7.70   augment 0.043
# tick 83    kimg 332.0    time 6h 43m 53s   sec/tick 283.5   sec/kimg 70.87   maintenance 0.3    cpumem 4.92   gpumem 7.69   augment 0.043
# tick 84    kimg 336.0    time 6h 48m 38s   sec/tick 284.3   sec/kimg 71.08   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.045
# tick 85    kimg 340.0    time 6h 53m 22s   sec/tick 284.1   sec/kimg 71.01   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.045
# tick 86    kimg 344.0    time 6h 58m 06s   sec/tick 284.1   sec/kimg 71.03   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.047
# tick 87    kimg 348.0    time 7h 02m 51s   sec/tick 284.4   sec/kimg 71.10   maintenance 0.3    cpumem 4.92   gpumem 7.69   augment 0.049
# tick 88    kimg 352.0    time 7h 07m 36s   sec/tick 284.4   sec/kimg 71.09   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.048
# tick 89    kimg 356.0    time 7h 12m 20s   sec/tick 283.5   sec/kimg 70.88   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.047
# tick 90    kimg 360.0    time 7h 17m 04s   sec/tick 284.3   sec/kimg 71.09   maintenance 0.3    cpumem 4.93   gpumem 7.68   augment 0.047
# tick 91    kimg 364.0    time 7h 21m 48s   sec/tick 283.6   sec/kimg 70.89   maintenance 0.3    cpumem 4.93   gpumem 7.69   augment 0.047
# tick 92    kimg 368.0    time 7h 26m 33s   sec/tick 284.4   sec/kimg 71.10   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.049
# tick 93    kimg 372.0    time 7h 31m 17s   sec/tick 283.9   sec/kimg 70.97   maintenance 0.3    cpumem 4.92   gpumem 7.69   augment 0.050
# tick 94    kimg 376.0    time 7h 36m 01s   sec/tick 283.7   sec/kimg 70.93   maintenance 0.3    cpumem 4.92   gpumem 7.69   augment 0.050
# tick 95    kimg 380.0    time 7h 40m 45s   sec/tick 283.8   sec/kimg 70.96   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.051
# tick 96    kimg 384.0    time 7h 45m 30s   sec/tick 284.4   sec/kimg 71.09   maintenance 0.3    cpumem 4.92   gpumem 7.72   augment 0.052
# tick 97    kimg 388.0    time 7h 50m 13s   sec/tick 283.5   sec/kimg 70.87   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.052
# tick 98    kimg 392.0    time 7h 54m 58s   sec/tick 284.5   sec/kimg 71.12   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.053
# tick 99    kimg 396.0    time 7h 59m 42s   sec/tick 283.5   sec/kimg 70.88   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.053
# tick 100   kimg 400.0    time 8h 04m 27s   sec/tick 284.2   sec/kimg 71.06   maintenance 0.3    cpumem 4.92   gpumem 7.68   augment 0.054
# Evaluating metrics...
# {"results": {"fid50k_full": 20.565336278291557}, "metric": "fid50k_full", "total_time": 382.0998079776764, "total_time_str": "6m 22s", "num_gpus": 2, "snapshot_pkl": "network-snapshot-000400.pkl", "timestamp": 1615223704.0364451}
# tick 101   kimg 404.0    time 8h 15m 37s   sec/tick 284.0   sec/kimg 71.00   maintenance 386.7  cpumem 4.97   gpumem 7.67   augment 0.053
# tick 102   kimg 408.0    time 8h 20m 20s   sec/tick 282.4   sec/kimg 70.60   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.054
# tick 103   kimg 412.0    time 8h 25m 02s   sec/tick 282.1   sec/kimg 70.53   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.053
# tick 104   kimg 416.0    time 8h 29m 45s   sec/tick 282.4   sec/kimg 70.59   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.052
# tick 105   kimg 420.0    time 8h 34m 27s   sec/tick 281.5   sec/kimg 70.38   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.052
# tick 106   kimg 424.0    time 8h 39m 10s   sec/tick 282.6   sec/kimg 70.64   maintenance 0.3    cpumem 4.97   gpumem 7.69   augment 0.053
# tick 107   kimg 428.0    time 8h 43m 52s   sec/tick 281.7   sec/kimg 70.42   maintenance 0.3    cpumem 4.97   gpumem 7.70   augment 0.054
# tick 108   kimg 432.0    time 8h 48m 34s   sec/tick 282.4   sec/kimg 70.59   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.054
# tick 109   kimg 436.0    time 8h 53m 17s   sec/tick 282.1   sec/kimg 70.53   maintenance 0.3    cpumem 4.97   gpumem 7.71   augment 0.054
# tick 110   kimg 440.0    time 8h 57m 59s   sec/tick 281.8   sec/kimg 70.45   maintenance 0.3    cpumem 4.97   gpumem 7.69   augment 0.055
# tick 111   kimg 444.0    time 9h 02m 41s   sec/tick 282.1   sec/kimg 70.51   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.056
# tick 112   kimg 448.0    time 9h 07m 24s   sec/tick 282.4   sec/kimg 70.59   maintenance 0.3    cpumem 4.97   gpumem 7.70   augment 0.056
# tick 113   kimg 452.0    time 9h 12m 05s   sec/tick 281.2   sec/kimg 70.31   maintenance 0.3    cpumem 4.97   gpumem 7.70   augment 0.056
# tick 114   kimg 456.0    time 9h 16m 48s   sec/tick 282.3   sec/kimg 70.58   maintenance 0.3    cpumem 4.97   gpumem 7.69   augment 0.056
# tick 115   kimg 460.0    time 9h 21m 30s   sec/tick 281.4   sec/kimg 70.35   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.054
# tick 116   kimg 464.0    time 9h 26m 12s   sec/tick 282.2   sec/kimg 70.56   maintenance 0.3    cpumem 4.97   gpumem 7.68   augment 0.054
# tick 117   kimg 468.0    time 9h 30m 54s   sec/tick 282.1   sec/kimg 70.52   maintenance 0.3    cpumem 4.97   gpumem 7.69   augment 0.055
# tick 118   kimg 472.0    time 9h 35m 37s   sec/tick 282.0   sec/kimg 70.50   maintenance 0.3    cpumem 4.97   gpumem 7.70   augment 0.057
# tick 119   kimg 476.0    time 9h 40m 19s   sec/tick 281.9   sec/kimg 70.47   maintenance 0.3    cpumem 4.97   gpumem 7.69   augment 0.057
# tick 120   kimg 480.0    time 9h 45m 01s   sec/tick 282.2   sec/kimg 70.54   maintenance 0.3    cpumem 4.97   gpumem 7.71   augment 0.055
# tick 121   kimg 484.0    time 9h 49m 43s   sec/tick 281.5   sec/kimg 70.38   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.056
# tick 122   kimg 488.0    time 9h 54m 26s   sec/tick 282.6   sec/kimg 70.64   maintenance 0.3    cpumem 4.96   gpumem 7.71   augment 0.056
# tick 123   kimg 492.0    time 9h 59m 08s   sec/tick 281.6   sec/kimg 70.40   maintenance 0.3    cpumem 4.96   gpumem 7.68   augment 0.056
# tick 124   kimg 496.0    time 10h 03m 51s  sec/tick 282.3   sec/kimg 70.57   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.055
# tick 125   kimg 500.0    time 10h 08m 33s  sec/tick 282.0   sec/kimg 70.49   maintenance 0.3    cpumem 4.96   gpumem 7.68   augment 0.056
# tick 126   kimg 504.0    time 10h 13m 15s  sec/tick 281.6   sec/kimg 70.39   maintenance 0.3    cpumem 4.96   gpumem 7.72   augment 0.057
# tick 127   kimg 508.0    time 10h 17m 57s  sec/tick 281.9   sec/kimg 70.48   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.058
# tick 128   kimg 512.0    time 10h 22m 40s  sec/tick 282.5   sec/kimg 70.63   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.057
# tick 129   kimg 516.0    time 10h 27m 21s  sec/tick 281.4   sec/kimg 70.35   maintenance 0.3    cpumem 4.96   gpumem 7.68   augment 0.057
# tick 130   kimg 520.0    time 10h 32m 04s  sec/tick 282.5   sec/kimg 70.63   maintenance 0.3    cpumem 4.96   gpumem 7.73   augment 0.058
# tick 131   kimg 524.0    time 10h 36m 46s  sec/tick 281.8   sec/kimg 70.44   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.059
# tick 132   kimg 528.0    time 10h 41m 29s  sec/tick 282.6   sec/kimg 70.65   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.059
# tick 133   kimg 532.0    time 10h 46m 11s  sec/tick 282.0   sec/kimg 70.51   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.059
# tick 134   kimg 536.0    time 10h 50m 54s  sec/tick 281.9   sec/kimg 70.47   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.059
# tick 135   kimg 540.0    time 10h 55m 36s  sec/tick 282.3   sec/kimg 70.58   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.059
# tick 136   kimg 544.0    time 11h 00m 19s  sec/tick 282.5   sec/kimg 70.62   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.058
# tick 137   kimg 548.0    time 11h 05m 00s  sec/tick 281.3   sec/kimg 70.32   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.058
# tick 138   kimg 552.0    time 11h 09m 43s  sec/tick 282.3   sec/kimg 70.57   maintenance 0.3    cpumem 4.96   gpumem 7.71   augment 0.059
# tick 139   kimg 556.0    time 11h 14m 25s  sec/tick 281.7   sec/kimg 70.42   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.060
# tick 140   kimg 560.0    time 11h 19m 08s  sec/tick 282.3   sec/kimg 70.57   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.061
# tick 141   kimg 564.0    time 11h 23m 50s  sec/tick 281.7   sec/kimg 70.43   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.060
# tick 142   kimg 568.0    time 11h 28m 31s  sec/tick 281.6   sec/kimg 70.39   maintenance 0.3    cpumem 4.96   gpumem 7.68   augment 0.060
# tick 143   kimg 572.0    time 11h 33m 13s  sec/tick 281.7   sec/kimg 70.43   maintenance 0.3    cpumem 4.96   gpumem 7.70   augment 0.060
# tick 144   kimg 576.0    time 11h 37m 56s  sec/tick 282.3   sec/kimg 70.57   maintenance 0.3    cpumem 4.95   gpumem 7.68   augment 0.060
# tick 145   kimg 580.0    time 11h 42m 37s  sec/tick 280.9   sec/kimg 70.24   maintenance 0.3    cpumem 4.95   gpumem 7.68   augment 0.059
# tick 146   kimg 584.0    time 11h 47m 19s  sec/tick 281.9   sec/kimg 70.47   maintenance 0.3    cpumem 4.96   gpumem 7.71   augment 0.061
# tick 147   kimg 588.0    time 11h 52m 01s  sec/tick 281.2   sec/kimg 70.29   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.061
# tick 148   kimg 592.0    time 11h 56m 43s  sec/tick 281.9   sec/kimg 70.48   maintenance 0.3    cpumem 4.96   gpumem 7.68   augment 0.062
# tick 149   kimg 596.0    time 12h 01m 25s  sec/tick 281.7   sec/kimg 70.43   maintenance 0.3    cpumem 4.96   gpumem 7.71   augment 0.063
# tick 150   kimg 600.0    time 12h 06m 06s  sec/tick 281.2   sec/kimg 70.29   maintenance 0.3    cpumem 4.96   gpumem 7.69   augment 0.061
# Evaluating metrics...
# {"results": {"fid50k_full": 20.51166223187922}, "metric": "fid50k_full", "total_time": 383.3137731552124, "total_time_str": "6m 23s", "num_gpus": 2, "snapshot_pkl": "network-snapshot-000600.pkl", "timestamp": 1615238205.299254}
# tick 151   kimg 604.0    time 12h 17m 18s  sec/tick 284.0   sec/kimg 71.00   maintenance 388.0  cpumem 4.97   gpumem 7.75   augment 0.062
# tick 152   kimg 608.0    time 12h 22m 05s  sec/tick 286.7   sec/kimg 71.67   maintenance 0.3    cpumem 4.97   gpumem 7.70   augment 0.063
# tick 153   kimg 612.0    time 12h 26m 51s  sec/tick 285.6   sec/kimg 71.40   maintenance 0.3    cpumem 4.97   gpumem 7.69   augment 0.063
# tick 154   kimg 616.0    time 12h 31m 38s  sec/tick 286.3   sec/kimg 71.58   maintenance 0.3    cpumem 4.97   gpumem 7.71   augment 0.062
# tick 155   kimg 620.0    time 12h 36m 24s  sec/tick 285.5   sec/kimg 71.38   maintenance 0.3    cpumem 4.97   gpumem 7.69   augment 0.063
# tick 156   kimg 624.0    time 12h 41m 10s  sec/tick 286.3   sec/kimg 71.58   maintenance 0.3    cpumem 4.97   gpumem 7.71   augment 0.063
# tick 157   kimg 628.0    time 12h 45m 57s  sec/tick 286.1   sec/kimg 71.53   maintenance 0.3    cpumem 4.94   gpumem 7.70   augment 0.063
# tick 158   kimg 632.0    time 12h 50m 43s  sec/tick 285.8   sec/kimg 71.46   maintenance 0.3    cpumem 4.94   gpumem 7.70   augment 0.060
# tick 159   kimg 636.0    time 12h 55m 29s  sec/tick 285.8   sec/kimg 71.45   maintenance 0.3    cpumem 4.94   gpumem 7.69   augment 0.061
# tick 160   kimg 640.0    time 13h 00m 15s  sec/tick 286.1   sec/kimg 71.52   maintenance 0.3    cpumem 4.94   gpumem 7.70   augment 0.062
# tick 161   kimg 644.0    time 13h 05m 01s  sec/tick 285.4   sec/kimg 71.34   maintenance 0.3    cpumem 4.94   gpumem 7.70   augment 0.062
# tick 162   kimg 648.0    time 13h 09m 48s  sec/tick 286.3   sec/kimg 71.56   maintenance 0.3    cpumem 4.94   gpumem 7.70   augment 0.061
# tick 163   kimg 652.0    time 13h 14m 33s  sec/tick 285.3   sec/kimg 71.31   maintenance 0.3    cpumem 4.94   gpumem 7.69   augment 0.061
# tick 164   kimg 656.0    time 13h 19m 19s  sec/tick 285.9   sec/kimg 71.47   maintenance 0.3    cpumem 4.94   gpumem 7.69   augment 0.059
# tick 165   kimg 660.0    time 13h 24m 05s  sec/tick 285.6   sec/kimg 71.40   maintenance 0.3    cpumem 4.94   gpumem 7.68   augment 0.060
# tick 166   kimg 664.0    time 13h 28m 51s  sec/tick 285.8   sec/kimg 71.45   maintenance 0.3    cpumem 4.94   gpumem 7.69   augment 0.061
# tick 167   kimg 668.0    time 13h 33m 37s  sec/tick 285.6   sec/kimg 71.39   maintenance 0.3    cpumem 4.94   gpumem 7.70   augment 0.062
# tick 168   kimg 672.0    time 13h 38m 24s  sec/tick 286.0   sec/kimg 71.51   maintenance 0.3    cpumem 4.94   gpumem 7.69   augment 0.061
# tick 169   kimg 676.0    time 13h 43m 09s  sec/tick 285.4   sec/kimg 71.34   maintenance 0.3    cpumem 4.94   gpumem 7.69   augment 0.060
# tick 170   kimg 680.0    time 13h 47m 56s  sec/tick 286.2   sec/kimg 71.55   maintenance 0.3    cpumem 4.94   gpumem 7.70   augment 0.061
# tick 171   kimg 684.0    time 13h 52m 41s  sec/tick 285.5   sec/kimg 71.37   maintenance 0.3    cpumem 4.94   gpumem 7.69   augment 0.061
# tick 172   kimg 688.0    time 13h 57m 28s  sec/tick 286.2   sec/kimg 71.55   maintenance 0.3    cpumem 4.88   gpumem 7.71   augment 0.062
# tick 173   kimg 692.0    time 14h 02m 14s  sec/tick 285.8   sec/kimg 71.44   maintenance 0.3    cpumem 4.88   gpumem 7.71   augment 0.061
# tick 174   kimg 696.0    time 14h 07m 00s  sec/tick 285.4   sec/kimg 71.35   maintenance 0.3    cpumem 4.88   gpumem 7.72   augment 0.062
# tick 175   kimg 700.0    time 14h 11m 46s  sec/tick 285.8   sec/kimg 71.44   maintenance 0.3    cpumem 4.88   gpumem 7.71   augment 0.063
# tick 176   kimg 704.0    time 14h 16m 32s  sec/tick 286.5   sec/kimg 71.62   maintenance 0.3    cpumem 4.88   gpumem 7.69   augment 0.063
# tick 177   kimg 708.0    time 14h 21m 18s  sec/tick 285.6   sec/kimg 71.41   maintenance 0.3    cpumem 4.88   gpumem 7.70   augment 0.061
# tick 178   kimg 712.0    time 14h 26m 05s  sec/tick 286.5   sec/kimg 71.62   maintenance 0.3    cpumem 4.88   gpumem 7.70   augment 0.063
# tick 179   kimg 716.0    time 14h 30m 51s  sec/tick 285.3   sec/kimg 71.31   maintenance 0.3    cpumem 4.88   gpumem 7.69   augment 0.063
# tick 180   kimg 720.0    time 14h 35m 37s  sec/tick 286.2   sec/kimg 71.54   maintenance 0.3    cpumem 4.88   gpumem 7.69   augment 0.062
# tick 181   kimg 724.0    time 14h 40m 23s  sec/tick 286.0   sec/kimg 71.49   maintenance 0.3    cpumem 4.88   gpumem 7.69   augment 0.064
# tick 182   kimg 728.0    time 14h 45m 10s  sec/tick 286.0   sec/kimg 71.49   maintenance 0.3    cpumem 4.88   gpumem 7.71   augment 0.065
# tick 183   kimg 732.0    time 14h 49m 56s  sec/tick 286.1   sec/kimg 71.53   maintenance 0.3    cpumem 4.88   gpumem 7.69   augment 0.066
# tick 184   kimg 736.0    time 14h 54m 43s  sec/tick 286.3   sec/kimg 71.57   maintenance 0.3    cpumem 4.88   gpumem 7.69   augment 0.063
# tick 185   kimg 740.0    time 14h 59m 28s  sec/tick 285.2   sec/kimg 71.31   maintenance 0.3    cpumem 4.88   gpumem 7.69   augment 0.062
# tick 186   kimg 744.0    time 15h 04m 14s  sec/tick 285.9   sec/kimg 71.47   maintenance 0.3    cpumem 4.88   gpumem 7.71   augment 0.063
# tick 187   kimg 748.0    time 15h 09m 00s  sec/tick 285.4   sec/kimg 71.35   maintenance 0.3    cpumem 4.81   gpumem 7.71   augment 0.064
# tick 188   kimg 752.0    time 15h 13m 46s  sec/tick 286.1   sec/kimg 71.53   maintenance 0.3    cpumem 4.81   gpumem 7.71   augment 0.066
# tick 189   kimg 756.0    time 15h 18m 32s  sec/tick 285.4   sec/kimg 71.35   maintenance 0.3    cpumem 4.81   gpumem 7.69   augment 0.065
# tick 190   kimg 760.0    time 15h 23m 18s  sec/tick 285.3   sec/kimg 71.34   maintenance 0.3    cpumem 4.81   gpumem 7.70   augment 0.067
# tick 191   kimg 764.0    time 15h 28m 04s  sec/tick 285.9   sec/kimg 71.48   maintenance 0.3    cpumem 4.81   gpumem 7.70   augment 0.066

# %% [markdown]
# ## Generate images

# %%
# !python generate_gray.py --outdir=./output_folder --seeds=number of seeds --network= path to netwrok

# %% [markdown]
# ### examples

# %%
# !python generate_gray.py --outdir=./output --seeds=0-1000 --network=./training-runs/00000-sunh-auto2-kimg1000/network-snapshot-000800.pkl
# Out:
# Loading networks from "./training-runs/00000-sunh-auto2-kimg1000/network-snapshot-000800.pkl"...
# Generating image for seed 0 (0/1001) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# torch.Size([512, 512])
# Generating image for seed 1 (1/1001) ...
# torch.Size([512, 512])
# Generating image for seed 2 (2/1001) ...
# torch.Size([512, 512])
# Generating image for seed 3 (3/1001) ...
# torch.Size([512, 512])
# Generating image for seed 4 (4/1001) ...
# torch.Size([512, 512])
# Generating image for seed 5 (5/1001) ...
# torch.Size([512, 512])
# Generating image for seed 6 (6/1001) ...
# torch.Size([512, 512])
# Generating image for seed 7 (7/1001) ...
# torch.Size([512, 512])
# Generating image for seed 8 (8/1001) ...
# torch.Size([512, 512])
# Generating image for seed 9 (9/1001) ...
# torch.Size([512, 512])
# Generating image for seed 10 (10/1001) ...
# torch.Size([512, 512])
# Generating image for seed 11 (11/1001) ...
# torch.Size([512, 512])
# Generating image for seed 12 (12/1001) ...
# torch.Size([512, 512])
# Generating image for seed 13 (13/1001) ...
# torch.Size([512, 512])
# Generating image for seed 14 (14/1001) ...
# torch.Size([512, 512])
# Generating image for seed 15 (15/1001) ...
# torch.Size([512, 512])
# Generating image for seed 16 (16/1001) ...
# torch.Size([512, 512])
# Generating image for seed 17 (17/1001) ...
# torch.Size([512, 512])
# Generating image for seed 18 (18/1001) ...
# torch.Size([512, 512])
# Generating image for seed 19 (19/1001) ...
# torch.Size([512, 512])
# Generating image for seed 20 (20/1001) ...
# torch.Size([512, 512])
# Generating image for seed 21 (21/1001) ...
# torch.Size([512, 512])
# Generating image for seed 22 (22/1001) ...
# torch.Size([512, 512])
# Generating image for seed 23 (23/1001) ...
# torch.Size([512, 512])
# Generating image for seed 24 (24/1001) ...
# torch.Size([512, 512])
# Generating image for seed 25 (25/1001) ...
# torch.Size([512, 512])
# Generating image for seed 26 (26/1001) ...
# torch.Size([512, 512])
# Generating image for seed 27 (27/1001) ...
# torch.Size([512, 512])
# Generating image for seed 28 (28/1001) ...
# torch.Size([512, 512])
# Generating image for seed 29 (29/1001) ...
# torch.Size([512, 512])
# Generating image for seed 30 (30/1001) ...
# torch.Size([512, 512])
# Generating image for seed 31 (31/1001) ...
# torch.Size([512, 512])
# Generating image for seed 32 (32/1001) ...
# torch.Size([512, 512])
# Generating image for seed 33 (33/1001) ...
# torch.Size([512, 512])
# Generating image for seed 34 (34/1001) ...
# torch.Size([512, 512])
# Generating image for seed 35 (35/1001) ...
# torch.Size([512, 512])
# Generating image for seed 36 (36/1001) ...
# torch.Size([512, 512])
# Generating image for seed 37 (37/1001) ...
# torch.Size([512, 512])
# Generating image for seed 38 (38/1001) ...
# torch.Size([512, 512])
# Generating image for seed 39 (39/1001) ...
# torch.Size([512, 512])
# Generating image for seed 40 (40/1001) ...
# torch.Size([512, 512])
# Generating image for seed 41 (41/1001) ...
# torch.Size([512, 512])
# Generating image for seed 42 (42/1001) ...
# torch.Size([512, 512])
# Generating image for seed 43 (43/1001) ...
# torch.Size([512, 512])
# Generating image for seed 44 (44/1001) ...
# torch.Size([512, 512])
# Generating image for seed 45 (45/1001) ...
# torch.Size([512, 512])
# Generating image for seed 46 (46/1001) ...
# torch.Size([512, 512])
# Generating image for seed 47 (47/1001) ...
# torch.Size([512, 512])
# Generating image for seed 48 (48/1001) ...
# torch.Size([512, 512])
# Generating image for seed 49 (49/1001) ...
# torch.Size([512, 512])
# Generating image for seed 50 (50/1001) ...
# torch.Size([512, 512])
# Generating image for seed 51 (51/1001) ...
# torch.Size([512, 512])
# Generating image for seed 52 (52/1001) ...
# torch.Size([512, 512])
# Generating image for seed 53 (53/1001) ...
# torch.Size([512, 512])
# Generating image for seed 54 (54/1001) ...
# torch.Size([512, 512])
# Generating image for seed 55 (55/1001) ...
# torch.Size([512, 512])
# Generating image for seed 56 (56/1001) ...
# torch.Size([512, 512])
# Generating image for seed 57 (57/1001) ...
# torch.Size([512, 512])
# Generating image for seed 58 (58/1001) ...
# torch.Size([512, 512])
# Generating image for seed 59 (59/1001) ...
# torch.Size([512, 512])
# Generating image for seed 60 (60/1001) ...
# torch.Size([512, 512])
# Generating image for seed 61 (61/1001) ...
# torch.Size([512, 512])
# Generating image for seed 62 (62/1001) ...
# torch.Size([512, 512])
# Generating image for seed 63 (63/1001) ...
# torch.Size([512, 512])
# Generating image for seed 64 (64/1001) ...
# torch.Size([512, 512])
# Generating image for seed 65 (65/1001) ...
# torch.Size([512, 512])
# Generating image for seed 66 (66/1001) ...
# torch.Size([512, 512])
# Generating image for seed 67 (67/1001) ...
# torch.Size([512, 512])
# Generating image for seed 68 (68/1001) ...
# torch.Size([512, 512])
# Generating image for seed 69 (69/1001) ...
# torch.Size([512, 512])
# Generating image for seed 70 (70/1001) ...
# torch.Size([512, 512])
# Generating image for seed 71 (71/1001) ...
# torch.Size([512, 512])
# Generating image for seed 72 (72/1001) ...
# torch.Size([512, 512])
# Generating image for seed 73 (73/1001) ...
# torch.Size([512, 512])
# Generating image for seed 74 (74/1001) ...
# torch.Size([512, 512])
# Generating image for seed 75 (75/1001) ...
# torch.Size([512, 512])
# Generating image for seed 76 (76/1001) ...
# torch.Size([512, 512])
# Generating image for seed 77 (77/1001) ...
# torch.Size([512, 512])
# Generating image for seed 78 (78/1001) ...
# torch.Size([512, 512])
# Generating image for seed 79 (79/1001) ...
# torch.Size([512, 512])
# Generating image for seed 80 (80/1001) ...
# torch.Size([512, 512])
# Generating image for seed 81 (81/1001) ...
# torch.Size([512, 512])
# Generating image for seed 82 (82/1001) ...
# torch.Size([512, 512])
# Generating image for seed 83 (83/1001) ...
# torch.Size([512, 512])
# Generating image for seed 84 (84/1001) ...
# torch.Size([512, 512])
# Generating image for seed 85 (85/1001) ...
# torch.Size([512, 512])
# Generating image for seed 86 (86/1001) ...
# torch.Size([512, 512])
# Generating image for seed 87 (87/1001) ...
# torch.Size([512, 512])
# Generating image for seed 88 (88/1001) ...
# torch.Size([512, 512])
# Generating image for seed 89 (89/1001) ...
# torch.Size([512, 512])
# Generating image for seed 90 (90/1001) ...
# torch.Size([512, 512])
# Generating image for seed 91 (91/1001) ...
# torch.Size([512, 512])
# Generating image for seed 92 (92/1001) ...
# torch.Size([512, 512])
# Generating image for seed 93 (93/1001) ...
# torch.Size([512, 512])
# Generating image for seed 94 (94/1001) ...
# torch.Size([512, 512])
# Generating image for seed 95 (95/1001) ...
# torch.Size([512, 512])
# Generating image for seed 96 (96/1001) ...
# torch.Size([512, 512])
# Generating image for seed 97 (97/1001) ...
# torch.Size([512, 512])
# Generating image for seed 98 (98/1001) ...
# torch.Size([512, 512])
# Generating image for seed 99 (99/1001) ...
# torch.Size([512, 512])
# Generating image for seed 100 (100/1001) ...
# torch.Size([512, 512])
# Generating image for seed 101 (101/1001) ...
# torch.Size([512, 512])
# Generating image for seed 102 (102/1001) ...
# torch.Size([512, 512])
# Generating image for seed 103 (103/1001) ...
# torch.Size([512, 512])
# Generating image for seed 104 (104/1001) ...
# torch.Size([512, 512])
# Generating image for seed 105 (105/1001) ...
# torch.Size([512, 512])
# Generating image for seed 106 (106/1001) ...
# torch.Size([512, 512])
# Generating image for seed 107 (107/1001) ...
# torch.Size([512, 512])
# Generating image for seed 108 (108/1001) ...
# torch.Size([512, 512])
# Generating image for seed 109 (109/1001) ...
# torch.Size([512, 512])
# Generating image for seed 110 (110/1001) ...
# torch.Size([512, 512])
# Generating image for seed 111 (111/1001) ...
# torch.Size([512, 512])
# Generating image for seed 112 (112/1001) ...
# torch.Size([512, 512])
# Generating image for seed 113 (113/1001) ...
# torch.Size([512, 512])
# Generating image for seed 114 (114/1001) ...
# torch.Size([512, 512])
# Generating image for seed 115 (115/1001) ...
# torch.Size([512, 512])
# Generating image for seed 116 (116/1001) ...
# torch.Size([512, 512])
# Generating image for seed 117 (117/1001) ...
# torch.Size([512, 512])
# Generating image for seed 118 (118/1001) ...
# torch.Size([512, 512])
# Generating image for seed 119 (119/1001) ...
# torch.Size([512, 512])
# Generating image for seed 120 (120/1001) ...
# torch.Size([512, 512])
# Generating image for seed 121 (121/1001) ...
# torch.Size([512, 512])
# Generating image for seed 122 (122/1001) ...
# torch.Size([512, 512])
# Generating image for seed 123 (123/1001) ...
# torch.Size([512, 512])
# Generating image for seed 124 (124/1001) ...
# torch.Size([512, 512])
# Generating image for seed 125 (125/1001) ...
# torch.Size([512, 512])
# Generating image for seed 126 (126/1001) ...
# torch.Size([512, 512])
# Generating image for seed 127 (127/1001) ...
# torch.Size([512, 512])
# Generating image for seed 128 (128/1001) ...
# torch.Size([512, 512])
# Generating image for seed 129 (129/1001) ...
# torch.Size([512, 512])
# Generating image for seed 130 (130/1001) ...
# torch.Size([512, 512])
# Generating image for seed 131 (131/1001) ...
# torch.Size([512, 512])
# Generating image for seed 132 (132/1001) ...
# torch.Size([512, 512])
# Generating image for seed 133 (133/1001) ...
# torch.Size([512, 512])
# Generating image for seed 134 (134/1001) ...
# torch.Size([512, 512])
# Generating image for seed 135 (135/1001) ...
# torch.Size([512, 512])
# Generating image for seed 136 (136/1001) ...
# torch.Size([512, 512])
# Generating image for seed 137 (137/1001) ...
# torch.Size([512, 512])
# Generating image for seed 138 (138/1001) ...
# torch.Size([512, 512])
# Generating image for seed 139 (139/1001) ...
# torch.Size([512, 512])
# Generating image for seed 140 (140/1001) ...
# torch.Size([512, 512])
# Generating image for seed 141 (141/1001) ...
# torch.Size([512, 512])
# Generating image for seed 142 (142/1001) ...
# torch.Size([512, 512])
# Generating image for seed 143 (143/1001) ...
# torch.Size([512, 512])
# Generating image for seed 144 (144/1001) ...
# torch.Size([512, 512])
# Generating image for seed 145 (145/1001) ...
# torch.Size([512, 512])
# Generating image for seed 146 (146/1001) ...
# torch.Size([512, 512])
# Generating image for seed 147 (147/1001) ...
# torch.Size([512, 512])
# Generating image for seed 148 (148/1001) ...
# torch.Size([512, 512])
# Generating image for seed 149 (149/1001) ...
# torch.Size([512, 512])
# Generating image for seed 150 (150/1001) ...
# torch.Size([512, 512])
# Generating image for seed 151 (151/1001) ...
# torch.Size([512, 512])
# Generating image for seed 152 (152/1001) ...
# torch.Size([512, 512])
# Generating image for seed 153 (153/1001) ...
# torch.Size([512, 512])
# Generating image for seed 154 (154/1001) ...
# torch.Size([512, 512])
# Generating image for seed 155 (155/1001) ...
# torch.Size([512, 512])
# Generating image for seed 156 (156/1001) ...
# torch.Size([512, 512])
# Generating image for seed 157 (157/1001) ...
# torch.Size([512, 512])
# Generating image for seed 158 (158/1001) ...
# torch.Size([512, 512])
# Generating image for seed 159 (159/1001) ...
# torch.Size([512, 512])
# Generating image for seed 160 (160/1001) ...
# torch.Size([512, 512])
# Generating image for seed 161 (161/1001) ...
# torch.Size([512, 512])
# Generating image for seed 162 (162/1001) ...
# torch.Size([512, 512])
# Generating image for seed 163 (163/1001) ...
# torch.Size([512, 512])
# Generating image for seed 164 (164/1001) ...
# torch.Size([512, 512])
# Generating image for seed 165 (165/1001) ...
# torch.Size([512, 512])
# Generating image for seed 166 (166/1001) ...
# torch.Size([512, 512])
# Generating image for seed 167 (167/1001) ...
# torch.Size([512, 512])
# Generating image for seed 168 (168/1001) ...
# torch.Size([512, 512])
# Generating image for seed 169 (169/1001) ...
# torch.Size([512, 512])
# Generating image for seed 170 (170/1001) ...
# torch.Size([512, 512])
# Generating image for seed 171 (171/1001) ...
# torch.Size([512, 512])
# Generating image for seed 172 (172/1001) ...
# torch.Size([512, 512])
# Generating image for seed 173 (173/1001) ...
# torch.Size([512, 512])
# Generating image for seed 174 (174/1001) ...
# torch.Size([512, 512])
# Generating image for seed 175 (175/1001) ...
# torch.Size([512, 512])
# Generating image for seed 176 (176/1001) ...
# torch.Size([512, 512])
# Generating image for seed 177 (177/1001) ...
# torch.Size([512, 512])
# Generating image for seed 178 (178/1001) ...
# torch.Size([512, 512])
# Generating image for seed 179 (179/1001) ...
# torch.Size([512, 512])
# Generating image for seed 180 (180/1001) ...
# torch.Size([512, 512])
# Generating image for seed 181 (181/1001) ...
# torch.Size([512, 512])
# Generating image for seed 182 (182/1001) ...
# torch.Size([512, 512])
# Generating image for seed 183 (183/1001) ...
# torch.Size([512, 512])
# Generating image for seed 184 (184/1001) ...
# torch.Size([512, 512])
# Generating image for seed 185 (185/1001) ...
# torch.Size([512, 512])
# Generating image for seed 186 (186/1001) ...
# torch.Size([512, 512])
# Generating image for seed 187 (187/1001) ...
# torch.Size([512, 512])
# Generating image for seed 188 (188/1001) ...
# torch.Size([512, 512])
# Generating image for seed 189 (189/1001) ...
# torch.Size([512, 512])
# Generating image for seed 190 (190/1001) ...
# torch.Size([512, 512])
# Generating image for seed 191 (191/1001) ...
# torch.Size([512, 512])
# Generating image for seed 192 (192/1001) ...
# torch.Size([512, 512])
# Generating image for seed 193 (193/1001) ...
# torch.Size([512, 512])
# Generating image for seed 194 (194/1001) ...
# torch.Size([512, 512])
# Generating image for seed 195 (195/1001) ...
# torch.Size([512, 512])
# Generating image for seed 196 (196/1001) ...
# torch.Size([512, 512])
# Generating image for seed 197 (197/1001) ...
# torch.Size([512, 512])
# Generating image for seed 198 (198/1001) ...
# torch.Size([512, 512])
# Generating image for seed 199 (199/1001) ...
# torch.Size([512, 512])
# Generating image for seed 200 (200/1001) ...
# torch.Size([512, 512])
# Generating image for seed 201 (201/1001) ...
# torch.Size([512, 512])
# Generating image for seed 202 (202/1001) ...
# torch.Size([512, 512])
# Generating image for seed 203 (203/1001) ...
# torch.Size([512, 512])
# Generating image for seed 204 (204/1001) ...
# torch.Size([512, 512])
# Generating image for seed 205 (205/1001) ...
# torch.Size([512, 512])
# Generating image for seed 206 (206/1001) ...
# torch.Size([512, 512])
# Generating image for seed 207 (207/1001) ...
# torch.Size([512, 512])
# Generating image for seed 208 (208/1001) ...
# torch.Size([512, 512])
# Generating image for seed 209 (209/1001) ...
# torch.Size([512, 512])
# Generating image for seed 210 (210/1001) ...
# torch.Size([512, 512])
# Generating image for seed 211 (211/1001) ...
# torch.Size([512, 512])
# Generating image for seed 212 (212/1001) ...
# torch.Size([512, 512])
# Generating image for seed 213 (213/1001) ...
# torch.Size([512, 512])
# Generating image for seed 214 (214/1001) ...
# torch.Size([512, 512])
# Generating image for seed 215 (215/1001) ...
# torch.Size([512, 512])
# Generating image for seed 216 (216/1001) ...
# torch.Size([512, 512])
# Generating image for seed 217 (217/1001) ...
# torch.Size([512, 512])
# Generating image for seed 218 (218/1001) ...
# torch.Size([512, 512])
# Generating image for seed 219 (219/1001) ...
# torch.Size([512, 512])
# Generating image for seed 220 (220/1001) ...
# torch.Size([512, 512])
# Generating image for seed 221 (221/1001) ...
# torch.Size([512, 512])
# Generating image for seed 222 (222/1001) ...
# torch.Size([512, 512])
# Generating image for seed 223 (223/1001) ...
# torch.Size([512, 512])
# Generating image for seed 224 (224/1001) ...
# torch.Size([512, 512])
# Generating image for seed 225 (225/1001) ...
# torch.Size([512, 512])
# Generating image for seed 226 (226/1001) ...
# torch.Size([512, 512])
# Generating image for seed 227 (227/1001) ...
# torch.Size([512, 512])
# Generating image for seed 228 (228/1001) ...
# torch.Size([512, 512])
# Generating image for seed 229 (229/1001) ...
# torch.Size([512, 512])
# Generating image for seed 230 (230/1001) ...
# torch.Size([512, 512])
# Generating image for seed 231 (231/1001) ...
# torch.Size([512, 512])
# Generating image for seed 232 (232/1001) ...
# torch.Size([512, 512])
# Generating image for seed 233 (233/1001) ...
# torch.Size([512, 512])
# Generating image for seed 234 (234/1001) ...
# torch.Size([512, 512])
# Generating image for seed 235 (235/1001) ...
# torch.Size([512, 512])
# Generating image for seed 236 (236/1001) ...
# torch.Size([512, 512])
# Generating image for seed 237 (237/1001) ...
# torch.Size([512, 512])
# Generating image for seed 238 (238/1001) ...
# torch.Size([512, 512])
# Generating image for seed 239 (239/1001) ...
# torch.Size([512, 512])
# Generating image for seed 240 (240/1001) ...
# torch.Size([512, 512])
# Generating image for seed 241 (241/1001) ...
# torch.Size([512, 512])
# Generating image for seed 242 (242/1001) ...
# torch.Size([512, 512])
# Generating image for seed 243 (243/1001) ...
# torch.Size([512, 512])
# Generating image for seed 244 (244/1001) ...
# torch.Size([512, 512])
# Generating image for seed 245 (245/1001) ...
# torch.Size([512, 512])
# Generating image for seed 246 (246/1001) ...
# torch.Size([512, 512])
# Generating image for seed 247 (247/1001) ...
# torch.Size([512, 512])
# Generating image for seed 248 (248/1001) ...
# torch.Size([512, 512])
# Generating image for seed 249 (249/1001) ...
# torch.Size([512, 512])
# Generating image for seed 250 (250/1001) ...
# torch.Size([512, 512])
# Generating image for seed 251 (251/1001) ...
# torch.Size([512, 512])
# Generating image for seed 252 (252/1001) ...
# torch.Size([512, 512])
# Generating image for seed 253 (253/1001) ...
# torch.Size([512, 512])
# Generating image for seed 254 (254/1001) ...
# torch.Size([512, 512])
# Generating image for seed 255 (255/1001) ...
# torch.Size([512, 512])
# Generating image for seed 256 (256/1001) ...
# torch.Size([512, 512])
# Generating image for seed 257 (257/1001) ...
# torch.Size([512, 512])
# Generating image for seed 258 (258/1001) ...
# torch.Size([512, 512])
# Generating image for seed 259 (259/1001) ...
# torch.Size([512, 512])
# Generating image for seed 260 (260/1001) ...
# torch.Size([512, 512])
# Generating image for seed 261 (261/1001) ...
# torch.Size([512, 512])
# Generating image for seed 262 (262/1001) ...
# torch.Size([512, 512])
# Generating image for seed 263 (263/1001) ...
# torch.Size([512, 512])
# Generating image for seed 264 (264/1001) ...
# torch.Size([512, 512])
# Generating image for seed 265 (265/1001) ...
# torch.Size([512, 512])
# Generating image for seed 266 (266/1001) ...
# torch.Size([512, 512])
# Generating image for seed 267 (267/1001) ...
# torch.Size([512, 512])
# Generating image for seed 268 (268/1001) ...
# torch.Size([512, 512])
# Generating image for seed 269 (269/1001) ...
# torch.Size([512, 512])
# Generating image for seed 270 (270/1001) ...
# torch.Size([512, 512])
# Generating image for seed 271 (271/1001) ...
# torch.Size([512, 512])
# Generating image for seed 272 (272/1001) ...
# torch.Size([512, 512])
# Generating image for seed 273 (273/1001) ...
# torch.Size([512, 512])
# Generating image for seed 274 (274/1001) ...
# torch.Size([512, 512])
# Generating image for seed 275 (275/1001) ...
# torch.Size([512, 512])
# Generating image for seed 276 (276/1001) ...
# torch.Size([512, 512])
# Generating image for seed 277 (277/1001) ...
# torch.Size([512, 512])
# Generating image for seed 278 (278/1001) ...
# torch.Size([512, 512])
# Generating image for seed 279 (279/1001) ...
# torch.Size([512, 512])
# Generating image for seed 280 (280/1001) ...
# torch.Size([512, 512])
# Generating image for seed 281 (281/1001) ...
# torch.Size([512, 512])
# Generating image for seed 282 (282/1001) ...
# torch.Size([512, 512])
# Generating image for seed 283 (283/1001) ...
# torch.Size([512, 512])
# Generating image for seed 284 (284/1001) ...
# torch.Size([512, 512])
# Generating image for seed 285 (285/1001) ...
# torch.Size([512, 512])
# Generating image for seed 286 (286/1001) ...
# torch.Size([512, 512])
# Generating image for seed 287 (287/1001) ...
# torch.Size([512, 512])
# Generating image for seed 288 (288/1001) ...
# torch.Size([512, 512])
# Generating image for seed 289 (289/1001) ...
# torch.Size([512, 512])
# Generating image for seed 290 (290/1001) ...
# torch.Size([512, 512])
# Generating image for seed 291 (291/1001) ...
# torch.Size([512, 512])
# Generating image for seed 292 (292/1001) ...
# torch.Size([512, 512])
# Generating image for seed 293 (293/1001) ...
# torch.Size([512, 512])
# Generating image for seed 294 (294/1001) ...
# torch.Size([512, 512])
# Generating image for seed 295 (295/1001) ...
# torch.Size([512, 512])
# Generating image for seed 296 (296/1001) ...
# torch.Size([512, 512])
# Generating image for seed 297 (297/1001) ...
# torch.Size([512, 512])
# Generating image for seed 298 (298/1001) ...
# torch.Size([512, 512])
# Generating image for seed 299 (299/1001) ...
# torch.Size([512, 512])
# Generating image for seed 300 (300/1001) ...
# torch.Size([512, 512])
# Generating image for seed 301 (301/1001) ...
# torch.Size([512, 512])
# Generating image for seed 302 (302/1001) ...
# torch.Size([512, 512])
# Generating image for seed 303 (303/1001) ...
# torch.Size([512, 512])
# Generating image for seed 304 (304/1001) ...
# torch.Size([512, 512])
# Generating image for seed 305 (305/1001) ...
# torch.Size([512, 512])
# Generating image for seed 306 (306/1001) ...
# torch.Size([512, 512])
# Generating image for seed 307 (307/1001) ...
# torch.Size([512, 512])
# Generating image for seed 308 (308/1001) ...
# torch.Size([512, 512])
# Generating image for seed 309 (309/1001) ...
# torch.Size([512, 512])
# Generating image for seed 310 (310/1001) ...
# torch.Size([512, 512])
# Generating image for seed 311 (311/1001) ...
# torch.Size([512, 512])
# Generating image for seed 312 (312/1001) ...
# torch.Size([512, 512])
# Generating image for seed 313 (313/1001) ...
# torch.Size([512, 512])
# Generating image for seed 314 (314/1001) ...
# torch.Size([512, 512])
# Generating image for seed 315 (315/1001) ...
# torch.Size([512, 512])
# Generating image for seed 316 (316/1001) ...
# torch.Size([512, 512])
# Generating image for seed 317 (317/1001) ...
# torch.Size([512, 512])
# Generating image for seed 318 (318/1001) ...
# torch.Size([512, 512])
# Generating image for seed 319 (319/1001) ...
# torch.Size([512, 512])
# Generating image for seed 320 (320/1001) ...
# torch.Size([512, 512])
# Generating image for seed 321 (321/1001) ...
# torch.Size([512, 512])
# Generating image for seed 322 (322/1001) ...
# torch.Size([512, 512])
# Generating image for seed 323 (323/1001) ...
# torch.Size([512, 512])
# Generating image for seed 324 (324/1001) ...
# torch.Size([512, 512])
# Generating image for seed 325 (325/1001) ...
# torch.Size([512, 512])
# Generating image for seed 326 (326/1001) ...
# torch.Size([512, 512])
# Generating image for seed 327 (327/1001) ...
# torch.Size([512, 512])
# Generating image for seed 328 (328/1001) ...
# torch.Size([512, 512])
# Generating image for seed 329 (329/1001) ...
# torch.Size([512, 512])
# Generating image for seed 330 (330/1001) ...
# torch.Size([512, 512])
# Generating image for seed 331 (331/1001) ...
# torch.Size([512, 512])
# Generating image for seed 332 (332/1001) ...
# torch.Size([512, 512])
# Generating image for seed 333 (333/1001) ...
# torch.Size([512, 512])
# Generating image for seed 334 (334/1001) ...
# torch.Size([512, 512])
# Generating image for seed 335 (335/1001) ...
# torch.Size([512, 512])
# Generating image for seed 336 (336/1001) ...
# torch.Size([512, 512])
# Generating image for seed 337 (337/1001) ...
# torch.Size([512, 512])
# Generating image for seed 338 (338/1001) ...
# torch.Size([512, 512])
# Generating image for seed 339 (339/1001) ...
# torch.Size([512, 512])
# Generating image for seed 340 (340/1001) ...
# torch.Size([512, 512])
# Generating image for seed 341 (341/1001) ...
# torch.Size([512, 512])
# Generating image for seed 342 (342/1001) ...
# torch.Size([512, 512])
# Generating image for seed 343 (343/1001) ...
# torch.Size([512, 512])
# Generating image for seed 344 (344/1001) ...
# torch.Size([512, 512])
# Generating image for seed 345 (345/1001) ...
# torch.Size([512, 512])
# Generating image for seed 346 (346/1001) ...
# torch.Size([512, 512])
# Generating image for seed 347 (347/1001) ...
# torch.Size([512, 512])
# Generating image for seed 348 (348/1001) ...
# torch.Size([512, 512])
# Generating image for seed 349 (349/1001) ...
# torch.Size([512, 512])
# Generating image for seed 350 (350/1001) ...
# torch.Size([512, 512])
# Generating image for seed 351 (351/1001) ...
# torch.Size([512, 512])
# Generating image for seed 352 (352/1001) ...
# torch.Size([512, 512])
# Generating image for seed 353 (353/1001) ...
# torch.Size([512, 512])
# Generating image for seed 354 (354/1001) ...
# torch.Size([512, 512])
# Generating image for seed 355 (355/1001) ...
# torch.Size([512, 512])
# Generating image for seed 356 (356/1001) ...
# torch.Size([512, 512])
# Generating image for seed 357 (357/1001) ...
# torch.Size([512, 512])
# Generating image for seed 358 (358/1001) ...
# torch.Size([512, 512])
# Generating image for seed 359 (359/1001) ...
# torch.Size([512, 512])
# Generating image for seed 360 (360/1001) ...
# torch.Size([512, 512])
# Generating image for seed 361 (361/1001) ...
# torch.Size([512, 512])
# Generating image for seed 362 (362/1001) ...
# torch.Size([512, 512])
# Generating image for seed 363 (363/1001) ...
# torch.Size([512, 512])
# Generating image for seed 364 (364/1001) ...
# torch.Size([512, 512])
# Generating image for seed 365 (365/1001) ...
# torch.Size([512, 512])
# Generating image for seed 366 (366/1001) ...
# torch.Size([512, 512])
# Generating image for seed 367 (367/1001) ...
# torch.Size([512, 512])
# Generating image for seed 368 (368/1001) ...
# torch.Size([512, 512])
# Generating image for seed 369 (369/1001) ...
# torch.Size([512, 512])
# Generating image for seed 370 (370/1001) ...
# torch.Size([512, 512])
# Generating image for seed 371 (371/1001) ...
# torch.Size([512, 512])
# Generating image for seed 372 (372/1001) ...
# torch.Size([512, 512])
# Generating image for seed 373 (373/1001) ...
# torch.Size([512, 512])
# Generating image for seed 374 (374/1001) ...
# torch.Size([512, 512])
# Generating image for seed 375 (375/1001) ...
# torch.Size([512, 512])
# Generating image for seed 376 (376/1001) ...
# torch.Size([512, 512])
# Generating image for seed 377 (377/1001) ...
# torch.Size([512, 512])
# Generating image for seed 378 (378/1001) ...
# torch.Size([512, 512])
# Generating image for seed 379 (379/1001) ...
# torch.Size([512, 512])
# Generating image for seed 380 (380/1001) ...
# torch.Size([512, 512])
# Generating image for seed 381 (381/1001) ...
# torch.Size([512, 512])
# Generating image for seed 382 (382/1001) ...
# torch.Size([512, 512])
# Generating image for seed 383 (383/1001) ...
# torch.Size([512, 512])
# Generating image for seed 384 (384/1001) ...
# torch.Size([512, 512])
# Generating image for seed 385 (385/1001) ...
# torch.Size([512, 512])
# Generating image for seed 386 (386/1001) ...
# torch.Size([512, 512])
# Generating image for seed 387 (387/1001) ...
# torch.Size([512, 512])
# Generating image for seed 388 (388/1001) ...
# torch.Size([512, 512])
# Generating image for seed 389 (389/1001) ...
# torch.Size([512, 512])
# Generating image for seed 390 (390/1001) ...
# torch.Size([512, 512])
# Generating image for seed 391 (391/1001) ...
# torch.Size([512, 512])
# Generating image for seed 392 (392/1001) ...
# torch.Size([512, 512])
# Generating image for seed 393 (393/1001) ...
# torch.Size([512, 512])
# Generating image for seed 394 (394/1001) ...
# torch.Size([512, 512])
# Generating image for seed 395 (395/1001) ...
# torch.Size([512, 512])
# Generating image for seed 396 (396/1001) ...
# torch.Size([512, 512])
# Generating image for seed 397 (397/1001) ...
# torch.Size([512, 512])
# Generating image for seed 398 (398/1001) ...
# torch.Size([512, 512])
# Generating image for seed 399 (399/1001) ...
# torch.Size([512, 512])
# Generating image for seed 400 (400/1001) ...
# torch.Size([512, 512])
# Generating image for seed 401 (401/1001) ...
# torch.Size([512, 512])
# Generating image for seed 402 (402/1001) ...
# torch.Size([512, 512])
# Generating image for seed 403 (403/1001) ...
# torch.Size([512, 512])
# Generating image for seed 404 (404/1001) ...
# torch.Size([512, 512])
# Generating image for seed 405 (405/1001) ...
# torch.Size([512, 512])
# Generating image for seed 406 (406/1001) ...
# torch.Size([512, 512])
# Generating image for seed 407 (407/1001) ...
# torch.Size([512, 512])
# Generating image for seed 408 (408/1001) ...
# torch.Size([512, 512])
# Generating image for seed 409 (409/1001) ...
# torch.Size([512, 512])
# Generating image for seed 410 (410/1001) ...
# torch.Size([512, 512])
# Generating image for seed 411 (411/1001) ...
# torch.Size([512, 512])
# Generating image for seed 412 (412/1001) ...
# torch.Size([512, 512])
# Generating image for seed 413 (413/1001) ...
# torch.Size([512, 512])
# Generating image for seed 414 (414/1001) ...
# torch.Size([512, 512])
# Generating image for seed 415 (415/1001) ...
# torch.Size([512, 512])
# Generating image for seed 416 (416/1001) ...
# torch.Size([512, 512])
# Generating image for seed 417 (417/1001) ...
# torch.Size([512, 512])
# Generating image for seed 418 (418/1001) ...
# torch.Size([512, 512])
# Generating image for seed 419 (419/1001) ...
# torch.Size([512, 512])
# Generating image for seed 420 (420/1001) ...
# torch.Size([512, 512])
# Generating image for seed 421 (421/1001) ...
# torch.Size([512, 512])
# Generating image for seed 422 (422/1001) ...
# torch.Size([512, 512])
# Generating image for seed 423 (423/1001) ...
# torch.Size([512, 512])
# Generating image for seed 424 (424/1001) ...
# torch.Size([512, 512])
# Generating image for seed 425 (425/1001) ...
# torch.Size([512, 512])
# Generating image for seed 426 (426/1001) ...
# torch.Size([512, 512])
# Generating image for seed 427 (427/1001) ...
# torch.Size([512, 512])
# Generating image for seed 428 (428/1001) ...
# torch.Size([512, 512])
# Generating image for seed 429 (429/1001) ...
# torch.Size([512, 512])
# Generating image for seed 430 (430/1001) ...
# torch.Size([512, 512])
# Generating image for seed 431 (431/1001) ...
# torch.Size([512, 512])
# Generating image for seed 432 (432/1001) ...
# torch.Size([512, 512])
# Generating image for seed 433 (433/1001) ...
# torch.Size([512, 512])
# Generating image for seed 434 (434/1001) ...
# torch.Size([512, 512])
# Generating image for seed 435 (435/1001) ...
# torch.Size([512, 512])
# Generating image for seed 436 (436/1001) ...
# torch.Size([512, 512])
# Generating image for seed 437 (437/1001) ...
# torch.Size([512, 512])
# Generating image for seed 438 (438/1001) ...
# torch.Size([512, 512])
# Generating image for seed 439 (439/1001) ...
# torch.Size([512, 512])
# Generating image for seed 440 (440/1001) ...
# torch.Size([512, 512])
# Generating image for seed 441 (441/1001) ...
# torch.Size([512, 512])
# Generating image for seed 442 (442/1001) ...
# torch.Size([512, 512])
# Generating image for seed 443 (443/1001) ...
# torch.Size([512, 512])
# Generating image for seed 444 (444/1001) ...
# torch.Size([512, 512])
# Generating image for seed 445 (445/1001) ...
# torch.Size([512, 512])
# Generating image for seed 446 (446/1001) ...
# torch.Size([512, 512])
# Generating image for seed 447 (447/1001) ...
# torch.Size([512, 512])
# Generating image for seed 448 (448/1001) ...
# torch.Size([512, 512])
# Generating image for seed 449 (449/1001) ...
# torch.Size([512, 512])
# Generating image for seed 450 (450/1001) ...
# torch.Size([512, 512])
# Generating image for seed 451 (451/1001) ...
# torch.Size([512, 512])
# Generating image for seed 452 (452/1001) ...
# torch.Size([512, 512])
# Generating image for seed 453 (453/1001) ...
# torch.Size([512, 512])
# Generating image for seed 454 (454/1001) ...
# torch.Size([512, 512])
# Generating image for seed 455 (455/1001) ...
# torch.Size([512, 512])
# Generating image for seed 456 (456/1001) ...
# torch.Size([512, 512])
# Generating image for seed 457 (457/1001) ...
# torch.Size([512, 512])
# Generating image for seed 458 (458/1001) ...
# torch.Size([512, 512])
# Generating image for seed 459 (459/1001) ...
# torch.Size([512, 512])
# Generating image for seed 460 (460/1001) ...
# torch.Size([512, 512])
# Generating image for seed 461 (461/1001) ...
# torch.Size([512, 512])
# Generating image for seed 462 (462/1001) ...
# torch.Size([512, 512])
# Generating image for seed 463 (463/1001) ...
# torch.Size([512, 512])
# Generating image for seed 464 (464/1001) ...
# torch.Size([512, 512])
# Generating image for seed 465 (465/1001) ...
# torch.Size([512, 512])
# Generating image for seed 466 (466/1001) ...
# torch.Size([512, 512])
# Generating image for seed 467 (467/1001) ...
# torch.Size([512, 512])
# Generating image for seed 468 (468/1001) ...
# torch.Size([512, 512])
# Generating image for seed 469 (469/1001) ...
# torch.Size([512, 512])
# Generating image for seed 470 (470/1001) ...
# torch.Size([512, 512])
# Generating image for seed 471 (471/1001) ...
# torch.Size([512, 512])
# Generating image for seed 472 (472/1001) ...
# torch.Size([512, 512])
# Generating image for seed 473 (473/1001) ...
# torch.Size([512, 512])
# Generating image for seed 474 (474/1001) ...
# torch.Size([512, 512])
# Generating image for seed 475 (475/1001) ...
# torch.Size([512, 512])
# Generating image for seed 476 (476/1001) ...
# torch.Size([512, 512])
# Generating image for seed 477 (477/1001) ...
# torch.Size([512, 512])
# Generating image for seed 478 (478/1001) ...
# torch.Size([512, 512])
# Generating image for seed 479 (479/1001) ...
# torch.Size([512, 512])
# Generating image for seed 480 (480/1001) ...
# torch.Size([512, 512])
# Generating image for seed 481 (481/1001) ...
# torch.Size([512, 512])
# Generating image for seed 482 (482/1001) ...
# torch.Size([512, 512])
# Generating image for seed 483 (483/1001) ...
# torch.Size([512, 512])
# Generating image for seed 484 (484/1001) ...
# torch.Size([512, 512])
# Generating image for seed 485 (485/1001) ...
# torch.Size([512, 512])
# Generating image for seed 486 (486/1001) ...
# torch.Size([512, 512])
# Generating image for seed 487 (487/1001) ...
# torch.Size([512, 512])
# Generating image for seed 488 (488/1001) ...
# torch.Size([512, 512])
# Generating image for seed 489 (489/1001) ...
# torch.Size([512, 512])
# Generating image for seed 490 (490/1001) ...
# torch.Size([512, 512])
# Generating image for seed 491 (491/1001) ...
# torch.Size([512, 512])
# Generating image for seed 492 (492/1001) ...
# torch.Size([512, 512])
# Generating image for seed 493 (493/1001) ...
# torch.Size([512, 512])
# Generating image for seed 494 (494/1001) ...
# torch.Size([512, 512])
# Generating image for seed 495 (495/1001) ...
# torch.Size([512, 512])
# Generating image for seed 496 (496/1001) ...
# torch.Size([512, 512])
# Generating image for seed 497 (497/1001) ...
# torch.Size([512, 512])
# Generating image for seed 498 (498/1001) ...
# torch.Size([512, 512])
# Generating image for seed 499 (499/1001) ...
# torch.Size([512, 512])
# Generating image for seed 500 (500/1001) ...
# torch.Size([512, 512])
# Generating image for seed 501 (501/1001) ...
# torch.Size([512, 512])
# Generating image for seed 502 (502/1001) ...
# torch.Size([512, 512])
# Generating image for seed 503 (503/1001) ...
# torch.Size([512, 512])
# Generating image for seed 504 (504/1001) ...
# torch.Size([512, 512])
# Generating image for seed 505 (505/1001) ...
# torch.Size([512, 512])
# Generating image for seed 506 (506/1001) ...
# torch.Size([512, 512])
# Generating image for seed 507 (507/1001) ...
# torch.Size([512, 512])
# Generating image for seed 508 (508/1001) ...
# torch.Size([512, 512])
# Generating image for seed 509 (509/1001) ...
# torch.Size([512, 512])
# Generating image for seed 510 (510/1001) ...
# torch.Size([512, 512])
# Generating image for seed 511 (511/1001) ...
# torch.Size([512, 512])
# Generating image for seed 512 (512/1001) ...
# torch.Size([512, 512])
# Generating image for seed 513 (513/1001) ...
# torch.Size([512, 512])
# Generating image for seed 514 (514/1001) ...
# torch.Size([512, 512])
# Generating image for seed 515 (515/1001) ...
# torch.Size([512, 512])
# Generating image for seed 516 (516/1001) ...
# torch.Size([512, 512])
# Generating image for seed 517 (517/1001) ...
# torch.Size([512, 512])
# Generating image for seed 518 (518/1001) ...
# torch.Size([512, 512])
# Generating image for seed 519 (519/1001) ...
# torch.Size([512, 512])
# Generating image for seed 520 (520/1001) ...
# torch.Size([512, 512])
# Generating image for seed 521 (521/1001) ...
# torch.Size([512, 512])
# Generating image for seed 522 (522/1001) ...
# torch.Size([512, 512])
# Generating image for seed 523 (523/1001) ...
# torch.Size([512, 512])
# Generating image for seed 524 (524/1001) ...
# torch.Size([512, 512])
# Generating image for seed 525 (525/1001) ...
# torch.Size([512, 512])
# Generating image for seed 526 (526/1001) ...
# torch.Size([512, 512])
# Generating image for seed 527 (527/1001) ...
# torch.Size([512, 512])
# Generating image for seed 528 (528/1001) ...
# torch.Size([512, 512])
# Generating image for seed 529 (529/1001) ...
# torch.Size([512, 512])
# Generating image for seed 530 (530/1001) ...
# torch.Size([512, 512])
# Generating image for seed 531 (531/1001) ...
# torch.Size([512, 512])
# Generating image for seed 532 (532/1001) ...
# torch.Size([512, 512])
# Generating image for seed 533 (533/1001) ...
# torch.Size([512, 512])
# Generating image for seed 534 (534/1001) ...
# torch.Size([512, 512])
# Generating image for seed 535 (535/1001) ...
# torch.Size([512, 512])
# Generating image for seed 536 (536/1001) ...
# torch.Size([512, 512])
# Generating image for seed 537 (537/1001) ...
# torch.Size([512, 512])
# Generating image for seed 538 (538/1001) ...
# torch.Size([512, 512])
# Generating image for seed 539 (539/1001) ...
# torch.Size([512, 512])
# Generating image for seed 540 (540/1001) ...
# torch.Size([512, 512])
# Generating image for seed 541 (541/1001) ...
# torch.Size([512, 512])
# Generating image for seed 542 (542/1001) ...
# torch.Size([512, 512])
# Generating image for seed 543 (543/1001) ...
# torch.Size([512, 512])
# Generating image for seed 544 (544/1001) ...
# torch.Size([512, 512])
# Generating image for seed 545 (545/1001) ...
# torch.Size([512, 512])
# Generating image for seed 546 (546/1001) ...
# torch.Size([512, 512])
# Generating image for seed 547 (547/1001) ...
# torch.Size([512, 512])
# Generating image for seed 548 (548/1001) ...
# torch.Size([512, 512])
# Generating image for seed 549 (549/1001) ...
# torch.Size([512, 512])
# Generating image for seed 550 (550/1001) ...
# torch.Size([512, 512])
# Generating image for seed 551 (551/1001) ...
# torch.Size([512, 512])
# Generating image for seed 552 (552/1001) ...
# torch.Size([512, 512])
# Generating image for seed 553 (553/1001) ...
# torch.Size([512, 512])
# Generating image for seed 554 (554/1001) ...
# torch.Size([512, 512])
# Generating image for seed 555 (555/1001) ...
# torch.Size([512, 512])
# Generating image for seed 556 (556/1001) ...
# torch.Size([512, 512])
# Generating image for seed 557 (557/1001) ...
# torch.Size([512, 512])
# Generating image for seed 558 (558/1001) ...
# torch.Size([512, 512])
# Generating image for seed 559 (559/1001) ...
# torch.Size([512, 512])
# Generating image for seed 560 (560/1001) ...
# torch.Size([512, 512])
# Generating image for seed 561 (561/1001) ...
# torch.Size([512, 512])
# Generating image for seed 562 (562/1001) ...
# torch.Size([512, 512])
# Generating image for seed 563 (563/1001) ...
# torch.Size([512, 512])
# Generating image for seed 564 (564/1001) ...
# torch.Size([512, 512])
# Generating image for seed 565 (565/1001) ...
# torch.Size([512, 512])
# Generating image for seed 566 (566/1001) ...
# torch.Size([512, 512])
# Generating image for seed 567 (567/1001) ...
# torch.Size([512, 512])
# Generating image for seed 568 (568/1001) ...
# torch.Size([512, 512])
# Generating image for seed 569 (569/1001) ...
# torch.Size([512, 512])
# Generating image for seed 570 (570/1001) ...
# torch.Size([512, 512])
# Generating image for seed 571 (571/1001) ...
# torch.Size([512, 512])
# Generating image for seed 572 (572/1001) ...
# torch.Size([512, 512])
# Generating image for seed 573 (573/1001) ...
# torch.Size([512, 512])
# Generating image for seed 574 (574/1001) ...
# torch.Size([512, 512])
# Generating image for seed 575 (575/1001) ...
# torch.Size([512, 512])
# Generating image for seed 576 (576/1001) ...
# torch.Size([512, 512])
# Generating image for seed 577 (577/1001) ...
# torch.Size([512, 512])
# Generating image for seed 578 (578/1001) ...
# torch.Size([512, 512])
# Generating image for seed 579 (579/1001) ...
# torch.Size([512, 512])
# Generating image for seed 580 (580/1001) ...
# torch.Size([512, 512])
# Generating image for seed 581 (581/1001) ...
# torch.Size([512, 512])
# Generating image for seed 582 (582/1001) ...
# torch.Size([512, 512])
# Generating image for seed 583 (583/1001) ...
# torch.Size([512, 512])
# Generating image for seed 584 (584/1001) ...
# torch.Size([512, 512])
# Generating image for seed 585 (585/1001) ...
# torch.Size([512, 512])
# Generating image for seed 586 (586/1001) ...
# torch.Size([512, 512])
# Generating image for seed 587 (587/1001) ...
# torch.Size([512, 512])
# Generating image for seed 588 (588/1001) ...
# torch.Size([512, 512])
# Generating image for seed 589 (589/1001) ...
# torch.Size([512, 512])
# Generating image for seed 590 (590/1001) ...
# torch.Size([512, 512])
# Generating image for seed 591 (591/1001) ...
# torch.Size([512, 512])
# Generating image for seed 592 (592/1001) ...
# torch.Size([512, 512])
# Generating image for seed 593 (593/1001) ...
# torch.Size([512, 512])
# Generating image for seed 594 (594/1001) ...
# torch.Size([512, 512])
# Generating image for seed 595 (595/1001) ...
# torch.Size([512, 512])
# Generating image for seed 596 (596/1001) ...
# torch.Size([512, 512])
# Generating image for seed 597 (597/1001) ...
# torch.Size([512, 512])
# Generating image for seed 598 (598/1001) ...
# torch.Size([512, 512])
# Generating image for seed 599 (599/1001) ...
# torch.Size([512, 512])
# Generating image for seed 600 (600/1001) ...
# torch.Size([512, 512])
# Generating image for seed 601 (601/1001) ...
# torch.Size([512, 512])
# Generating image for seed 602 (602/1001) ...
# torch.Size([512, 512])
# Generating image for seed 603 (603/1001) ...
# torch.Size([512, 512])
# Generating image for seed 604 (604/1001) ...
# torch.Size([512, 512])
# Generating image for seed 605 (605/1001) ...
# torch.Size([512, 512])
# Generating image for seed 606 (606/1001) ...
# torch.Size([512, 512])
# Generating image for seed 607 (607/1001) ...
# torch.Size([512, 512])
# Generating image for seed 608 (608/1001) ...
# torch.Size([512, 512])
# Generating image for seed 609 (609/1001) ...
# torch.Size([512, 512])
# Generating image for seed 610 (610/1001) ...
# torch.Size([512, 512])
# Generating image for seed 611 (611/1001) ...
# torch.Size([512, 512])
# Generating image for seed 612 (612/1001) ...
# torch.Size([512, 512])
# Generating image for seed 613 (613/1001) ...
# torch.Size([512, 512])
# Generating image for seed 614 (614/1001) ...
# torch.Size([512, 512])
# Generating image for seed 615 (615/1001) ...
# torch.Size([512, 512])
# Generating image for seed 616 (616/1001) ...
# torch.Size([512, 512])
# Generating image for seed 617 (617/1001) ...
# torch.Size([512, 512])
# Generating image for seed 618 (618/1001) ...
# torch.Size([512, 512])
# Generating image for seed 619 (619/1001) ...
# torch.Size([512, 512])
# Generating image for seed 620 (620/1001) ...
# torch.Size([512, 512])
# Generating image for seed 621 (621/1001) ...
# torch.Size([512, 512])
# Generating image for seed 622 (622/1001) ...
# torch.Size([512, 512])
# Generating image for seed 623 (623/1001) ...
# torch.Size([512, 512])
# Generating image for seed 624 (624/1001) ...
# torch.Size([512, 512])
# Generating image for seed 625 (625/1001) ...
# torch.Size([512, 512])
# Generating image for seed 626 (626/1001) ...
# torch.Size([512, 512])
# Generating image for seed 627 (627/1001) ...
# torch.Size([512, 512])
# Generating image for seed 628 (628/1001) ...
# torch.Size([512, 512])
# Generating image for seed 629 (629/1001) ...
# torch.Size([512, 512])
# Generating image for seed 630 (630/1001) ...
# torch.Size([512, 512])
# Generating image for seed 631 (631/1001) ...
# torch.Size([512, 512])
# Generating image for seed 632 (632/1001) ...
# torch.Size([512, 512])
# Generating image for seed 633 (633/1001) ...
# torch.Size([512, 512])
# Generating image for seed 634 (634/1001) ...
# torch.Size([512, 512])
# Generating image for seed 635 (635/1001) ...
# torch.Size([512, 512])
# Generating image for seed 636 (636/1001) ...
# torch.Size([512, 512])
# Generating image for seed 637 (637/1001) ...
# torch.Size([512, 512])
# Generating image for seed 638 (638/1001) ...
# torch.Size([512, 512])
# Generating image for seed 639 (639/1001) ...
# torch.Size([512, 512])
# Generating image for seed 640 (640/1001) ...
# torch.Size([512, 512])
# Generating image for seed 641 (641/1001) ...
# torch.Size([512, 512])
# Generating image for seed 642 (642/1001) ...
# torch.Size([512, 512])
# Generating image for seed 643 (643/1001) ...
# torch.Size([512, 512])
# Generating image for seed 644 (644/1001) ...
# torch.Size([512, 512])
# Generating image for seed 645 (645/1001) ...
# torch.Size([512, 512])
# Generating image for seed 646 (646/1001) ...
# torch.Size([512, 512])
# Generating image for seed 647 (647/1001) ...
# torch.Size([512, 512])
# Generating image for seed 648 (648/1001) ...
# torch.Size([512, 512])
# Generating image for seed 649 (649/1001) ...
# torch.Size([512, 512])
# Generating image for seed 650 (650/1001) ...
# torch.Size([512, 512])
# Generating image for seed 651 (651/1001) ...
# torch.Size([512, 512])
# Generating image for seed 652 (652/1001) ...
# torch.Size([512, 512])
# Generating image for seed 653 (653/1001) ...
# torch.Size([512, 512])
# Generating image for seed 654 (654/1001) ...
# torch.Size([512, 512])
# Generating image for seed 655 (655/1001) ...
# torch.Size([512, 512])
# Generating image for seed 656 (656/1001) ...
# torch.Size([512, 512])
# Generating image for seed 657 (657/1001) ...
# torch.Size([512, 512])
# Generating image for seed 658 (658/1001) ...
# torch.Size([512, 512])
# Generating image for seed 659 (659/1001) ...
# torch.Size([512, 512])
# Generating image for seed 660 (660/1001) ...
# torch.Size([512, 512])
# Generating image for seed 661 (661/1001) ...
# torch.Size([512, 512])
# Generating image for seed 662 (662/1001) ...
# torch.Size([512, 512])
# Generating image for seed 663 (663/1001) ...
# torch.Size([512, 512])
# Generating image for seed 664 (664/1001) ...
# torch.Size([512, 512])
# Generating image for seed 665 (665/1001) ...
# torch.Size([512, 512])
# Generating image for seed 666 (666/1001) ...
# torch.Size([512, 512])
# Generating image for seed 667 (667/1001) ...
# torch.Size([512, 512])
# Generating image for seed 668 (668/1001) ...
# torch.Size([512, 512])
# Generating image for seed 669 (669/1001) ...
# torch.Size([512, 512])
# Generating image for seed 670 (670/1001) ...
# torch.Size([512, 512])
# Generating image for seed 671 (671/1001) ...
# torch.Size([512, 512])
# Generating image for seed 672 (672/1001) ...
# torch.Size([512, 512])
# Generating image for seed 673 (673/1001) ...
# torch.Size([512, 512])
# Generating image for seed 674 (674/1001) ...
# torch.Size([512, 512])
# Generating image for seed 675 (675/1001) ...
# torch.Size([512, 512])
# Generating image for seed 676 (676/1001) ...
# torch.Size([512, 512])
# Generating image for seed 677 (677/1001) ...
# torch.Size([512, 512])
# Generating image for seed 678 (678/1001) ...
# torch.Size([512, 512])
# Generating image for seed 679 (679/1001) ...
# torch.Size([512, 512])
# Generating image for seed 680 (680/1001) ...
# torch.Size([512, 512])
# Generating image for seed 681 (681/1001) ...
# torch.Size([512, 512])
# Generating image for seed 682 (682/1001) ...
# torch.Size([512, 512])
# Generating image for seed 683 (683/1001) ...
# torch.Size([512, 512])
# Generating image for seed 684 (684/1001) ...
# torch.Size([512, 512])
# Generating image for seed 685 (685/1001) ...
# torch.Size([512, 512])
# Generating image for seed 686 (686/1001) ...
# torch.Size([512, 512])
# Generating image for seed 687 (687/1001) ...
# torch.Size([512, 512])
# Generating image for seed 688 (688/1001) ...
# torch.Size([512, 512])
# Generating image for seed 689 (689/1001) ...
# torch.Size([512, 512])
# Generating image for seed 690 (690/1001) ...
# torch.Size([512, 512])
# Generating image for seed 691 (691/1001) ...
# torch.Size([512, 512])
# Generating image for seed 692 (692/1001) ...
# torch.Size([512, 512])
# Generating image for seed 693 (693/1001) ...
# torch.Size([512, 512])
# Generating image for seed 694 (694/1001) ...
# torch.Size([512, 512])
# Generating image for seed 695 (695/1001) ...
# torch.Size([512, 512])
# Generating image for seed 696 (696/1001) ...
# torch.Size([512, 512])
# Generating image for seed 697 (697/1001) ...
# torch.Size([512, 512])
# Generating image for seed 698 (698/1001) ...
# torch.Size([512, 512])
# Generating image for seed 699 (699/1001) ...
# torch.Size([512, 512])
# Generating image for seed 700 (700/1001) ...
# torch.Size([512, 512])
# Generating image for seed 701 (701/1001) ...
# torch.Size([512, 512])
# Generating image for seed 702 (702/1001) ...
# torch.Size([512, 512])
# Generating image for seed 703 (703/1001) ...
# torch.Size([512, 512])
# Generating image for seed 704 (704/1001) ...
# torch.Size([512, 512])
# Generating image for seed 705 (705/1001) ...
# torch.Size([512, 512])
# ...
# Generating image for seed 766 (766/1001) ...
# torch.Size([512, 512])
# Generating image for seed 767 (767/1001) ...
# torch.Size([512, 512])
# Generating image for seed 768 (768/1001) ...
# torch.Size([512, 512])
# Generating image for seed 769 (769/1001) ...
# torch.Size([512, 512])
# Generating image for seed 770 (770/1001) ...
# torch.Size([512, 512])
# Generating image for seed 771 (771/1001) ...
# torch.Size([512, 512])
# Generating image for seed 772 (772/1001) ...
# torch.Size([512, 512])
# Generating image for seed 773 (773/1001) ...
# torch.Size([512, 512])
# Generating image for seed 774 (774/1001) ...
# torch.Size([512, 512])
# Generating image for seed 775 (775/1001) ...
# torch.Size([512, 512])
# Generating image for seed 776 (776/1001) ...
# torch.Size([512, 512])
# Generating image for seed 777 (777/1001) ...
# torch.Size([512, 512])
# Generating image for seed 778 (778/1001) ...
# torch.Size([512, 512])
# Generating image for seed 779 (779/1001) ...
# torch.Size([512, 512])
# Generating image for seed 780 (780/1001) ...
# torch.Size([512, 512])
# Generating image for seed 781 (781/1001) ...
# torch.Size([512, 512])
# Generating image for seed 782 (782/1001) ...
# torch.Size([512, 512])
# Generating image for seed 783 (783/1001) ...
# torch.Size([512, 512])
# Generating image for seed 784 (784/1001) ...
# torch.Size([512, 512])
# Generating image for seed 785 (785/1001) ...
# torch.Size([512, 512])
# Generating image for seed 786 (786/1001) ...
# torch.Size([512, 512])
# Generating image for seed 787 (787/1001) ...
# torch.Size([512, 512])
# Generating image for seed 788 (788/1001) ...
# torch.Size([512, 512])
# Generating image for seed 789 (789/1001) ...
# torch.Size([512, 512])
# Generating image for seed 790 (790/1001) ...
# torch.Size([512, 512])
# Generating image for seed 791 (791/1001) ...
# torch.Size([512, 512])
# Generating image for seed 792 (792/1001) ...
# torch.Size([512, 512])
# Generating image for seed 793 (793/1001) ...
# torch.Size([512, 512])
# Generating image for seed 794 (794/1001) ...
# torch.Size([512, 512])
# Generating image for seed 795 (795/1001) ...
# torch.Size([512, 512])
# Generating image for seed 796 (796/1001) ...
# torch.Size([512, 512])
# Generating image for seed 797 (797/1001) ...
# torch.Size([512, 512])
# Generating image for seed 798 (798/1001) ...
# torch.Size([512, 512])
# Generating image for seed 799 (799/1001) ...
# torch.Size([512, 512])
# Generating image for seed 800 (800/1001) ...
# torch.Size([512, 512])
# Generating image for seed 801 (801/1001) ...
# torch.Size([512, 512])
# Generating image for seed 802 (802/1001) ...
# torch.Size([512, 512])
# Generating image for seed 803 (803/1001) ...
# torch.Size([512, 512])
# Generating image for seed 804 (804/1001) ...
# torch.Size([512, 512])
# Generating image for seed 805 (805/1001) ...
# torch.Size([512, 512])
# Generating image for seed 806 (806/1001) ...
# torch.Size([512, 512])
# Generating image for seed 807 (807/1001) ...
# torch.Size([512, 512])
# Generating image for seed 808 (808/1001) ...
# torch.Size([512, 512])
# Generating image for seed 809 (809/1001) ...
# torch.Size([512, 512])
# Generating image for seed 810 (810/1001) ...
# torch.Size([512, 512])
# Generating image for seed 811 (811/1001) ...
# torch.Size([512, 512])
# Generating image for seed 812 (812/1001) ...
# torch.Size([512, 512])
# Generating image for seed 813 (813/1001) ...
# torch.Size([512, 512])
# Generating image for seed 814 (814/1001) ...
# torch.Size([512, 512])
# Generating image for seed 815 (815/1001) ...
# torch.Size([512, 512])
# Generating image for seed 816 (816/1001) ...
# torch.Size([512, 512])
# Generating image for seed 817 (817/1001) ...
# torch.Size([512, 512])
# Generating image for seed 818 (818/1001) ...
# torch.Size([512, 512])
# Generating image for seed 819 (819/1001) ...
# torch.Size([512, 512])
# Generating image for seed 820 (820/1001) ...
# torch.Size([512, 512])
# Generating image for seed 821 (821/1001) ...
# torch.Size([512, 512])
# Generating image for seed 822 (822/1001) ...
# torch.Size([512, 512])
# Generating image for seed 823 (823/1001) ...
# torch.Size([512, 512])
# Generating image for seed 824 (824/1001) ...
# torch.Size([512, 512])
# Generating image for seed 825 (825/1001) ...
# torch.Size([512, 512])
# Generating image for seed 826 (826/1001) ...
# torch.Size([512, 512])
# Generating image for seed 827 (827/1001) ...
# torch.Size([512, 512])
# Generating image for seed 828 (828/1001) ...
# torch.Size([512, 512])
# Generating image for seed 829 (829/1001) ...
# torch.Size([512, 512])
# Generating image for seed 830 (830/1001) ...
# torch.Size([512, 512])
# Generating image for seed 831 (831/1001) ...
# torch.Size([512, 512])
# Generating image for seed 832 (832/1001) ...
# torch.Size([512, 512])
# Generating image for seed 833 (833/1001) ...
# torch.Size([512, 512])
# Generating image for seed 834 (834/1001) ...
# torch.Size([512, 512])
# Generating image for seed 835 (835/1001) ...
# torch.Size([512, 512])
# Generating image for seed 836 (836/1001) ...
# torch.Size([512, 512])
# Generating image for seed 837 (837/1001) ...
# torch.Size([512, 512])
# Generating image for seed 838 (838/1001) ...
# torch.Size([512, 512])
# Generating image for seed 839 (839/1001) ...
# torch.Size([512, 512])
# Generating image for seed 840 (840/1001) ...
# torch.Size([512, 512])
# Generating image for seed 841 (841/1001) ...
# torch.Size([512, 512])
# Generating image for seed 842 (842/1001) ...
# torch.Size([512, 512])
# Generating image for seed 843 (843/1001) ...
# torch.Size([512, 512])
# Generating image for seed 844 (844/1001) ...
# torch.Size([512, 512])
# Generating image for seed 845 (845/1001) ...
# torch.Size([512, 512])
# Generating image for seed 846 (846/1001) ...
# torch.Size([512, 512])
# Generating image for seed 847 (847/1001) ...
# torch.Size([512, 512])
# Generating image for seed 848 (848/1001) ...
# torch.Size([512, 512])
# Generating image for seed 849 (849/1001) ...
# torch.Size([512, 512])
# Generating image for seed 850 (850/1001) ...
# torch.Size([512, 512])
# Generating image for seed 851 (851/1001) ...
# torch.Size([512, 512])
# Generating image for seed 852 (852/1001) ...
# torch.Size([512, 512])
# Generating image for seed 853 (853/1001) ...
# torch.Size([512, 512])
# Generating image for seed 854 (854/1001) ...
# torch.Size([512, 512])
# Generating image for seed 855 (855/1001) ...
# torch.Size([512, 512])
# Generating image for seed 856 (856/1001) ...
# torch.Size([512, 512])
# Generating image for seed 857 (857/1001) ...
# torch.Size([512, 512])
# Generating image for seed 858 (858/1001) ...
# torch.Size([512, 512])
# Generating image for seed 859 (859/1001) ...
# torch.Size([512, 512])
# Generating image for seed 860 (860/1001) ...
# torch.Size([512, 512])
# Generating image for seed 861 (861/1001) ...
# torch.Size([512, 512])
# Generating image for seed 862 (862/1001) ...
# torch.Size([512, 512])
# Generating image for seed 863 (863/1001) ...
# torch.Size([512, 512])
# Generating image for seed 864 (864/1001) ...
# torch.Size([512, 512])
# Generating image for seed 865 (865/1001) ...
# torch.Size([512, 512])
# Generating image for seed 866 (866/1001) ...
# torch.Size([512, 512])
# Generating image for seed 867 (867/1001) ...
# torch.Size([512, 512])
# Generating image for seed 868 (868/1001) ...
# torch.Size([512, 512])
# Generating image for seed 869 (869/1001) ...
# torch.Size([512, 512])
# Generating image for seed 870 (870/1001) ...
# torch.Size([512, 512])
# Generating image for seed 871 (871/1001) ...
# torch.Size([512, 512])
# Generating image for seed 872 (872/1001) ...
# torch.Size([512, 512])
# Generating image for seed 873 (873/1001) ...
# torch.Size([512, 512])
# Generating image for seed 874 (874/1001) ...
# torch.Size([512, 512])
# Generating image for seed 875 (875/1001) ...
# torch.Size([512, 512])
# Generating image for seed 876 (876/1001) ...
# torch.Size([512, 512])
# Generating image for seed 877 (877/1001) ...
# torch.Size([512, 512])
# Generating image for seed 878 (878/1001) ...
# torch.Size([512, 512])
# Generating image for seed 879 (879/1001) ...
# torch.Size([512, 512])
# Generating image for seed 880 (880/1001) ...
# torch.Size([512, 512])
# Generating image for seed 881 (881/1001) ...
# torch.Size([512, 512])
# Generating image for seed 882 (882/1001) ...
# torch.Size([512, 512])
# Generating image for seed 883 (883/1001) ...
# torch.Size([512, 512])
# Generating image for seed 884 (884/1001) ...
# torch.Size([512, 512])
# Generating image for seed 885 (885/1001) ...
# torch.Size([512, 512])
# Generating image for seed 886 (886/1001) ...
# torch.Size([512, 512])
# Generating image for seed 887 (887/1001) ...
# torch.Size([512, 512])
# Generating image for seed 888 (888/1001) ...
# torch.Size([512, 512])
# Generating image for seed 889 (889/1001) ...
# torch.Size([512, 512])
# Generating image for seed 890 (890/1001) ...
# torch.Size([512, 512])
# Generating image for seed 891 (891/1001) ...
# torch.Size([512, 512])
# Generating image for seed 892 (892/1001) ...
# torch.Size([512, 512])
# Generating image for seed 893 (893/1001) ...
# torch.Size([512, 512])
# Generating image for seed 894 (894/1001) ...
# torch.Size([512, 512])
# Generating image for seed 895 (895/1001) ...
# torch.Size([512, 512])
# Generating image for seed 896 (896/1001) ...
# torch.Size([512, 512])
# Generating image for seed 897 (897/1001) ...
# torch.Size([512, 512])
# Generating image for seed 898 (898/1001) ...
# torch.Size([512, 512])
# Generating image for seed 899 (899/1001) ...
# torch.Size([512, 512])
# Generating image for seed 900 (900/1001) ...
# torch.Size([512, 512])
# Generating image for seed 901 (901/1001) ...
# torch.Size([512, 512])
# Generating image for seed 902 (902/1001) ...
# torch.Size([512, 512])
# Generating image for seed 903 (903/1001) ...
# torch.Size([512, 512])
# Generating image for seed 904 (904/1001) ...
# torch.Size([512, 512])
# Generating image for seed 905 (905/1001) ...
# torch.Size([512, 512])
# Generating image for seed 906 (906/1001) ...
# torch.Size([512, 512])
# Generating image for seed 907 (907/1001) ...
# torch.Size([512, 512])
# Generating image for seed 908 (908/1001) ...
# torch.Size([512, 512])
# Generating image for seed 909 (909/1001) ...
# torch.Size([512, 512])
# Generating image for seed 910 (910/1001) ...
# torch.Size([512, 512])
# Generating image for seed 911 (911/1001) ...
# torch.Size([512, 512])
# Generating image for seed 912 (912/1001) ...
# torch.Size([512, 512])
# Generating image for seed 913 (913/1001) ...
# torch.Size([512, 512])
# Generating image for seed 914 (914/1001) ...
# torch.Size([512, 512])
# Generating image for seed 915 (915/1001) ...
# torch.Size([512, 512])
# Generating image for seed 916 (916/1001) ...
# torch.Size([512, 512])
# Generating image for seed 917 (917/1001) ...
# torch.Size([512, 512])
# Generating image for seed 918 (918/1001) ...
# torch.Size([512, 512])
# Generating image for seed 919 (919/1001) ...
# torch.Size([512, 512])
# Generating image for seed 920 (920/1001) ...
# torch.Size([512, 512])
# Generating image for seed 921 (921/1001) ...
# torch.Size([512, 512])
# Generating image for seed 922 (922/1001) ...
# torch.Size([512, 512])
# Generating image for seed 923 (923/1001) ...
# torch.Size([512, 512])
# Generating image for seed 924 (924/1001) ...
# torch.Size([512, 512])
# Generating image for seed 925 (925/1001) ...
# torch.Size([512, 512])
# Generating image for seed 926 (926/1001) ...
# torch.Size([512, 512])
# Generating image for seed 927 (927/1001) ...
# torch.Size([512, 512])
# Generating image for seed 928 (928/1001) ...
# torch.Size([512, 512])
# Generating image for seed 929 (929/1001) ...
# torch.Size([512, 512])
# Generating image for seed 930 (930/1001) ...
# torch.Size([512, 512])
# Generating image for seed 931 (931/1001) ...
# torch.Size([512, 512])
# Generating image for seed 932 (932/1001) ...
# torch.Size([512, 512])
# Generating image for seed 933 (933/1001) ...
# torch.Size([512, 512])
# Generating image for seed 934 (934/1001) ...
# torch.Size([512, 512])
# Generating image for seed 935 (935/1001) ...
# torch.Size([512, 512])
# Generating image for seed 936 (936/1001) ...
# torch.Size([512, 512])
# Generating image for seed 937 (937/1001) ...
# torch.Size([512, 512])
# Generating image for seed 938 (938/1001) ...
# torch.Size([512, 512])
# Generating image for seed 939 (939/1001) ...
# torch.Size([512, 512])
# Generating image for seed 940 (940/1001) ...
# torch.Size([512, 512])
# Generating image for seed 941 (941/1001) ...
# torch.Size([512, 512])
# Generating image for seed 942 (942/1001) ...
# torch.Size([512, 512])
# Generating image for seed 943 (943/1001) ...
# torch.Size([512, 512])
# Generating image for seed 944 (944/1001) ...
# torch.Size([512, 512])
# Generating image for seed 945 (945/1001) ...
# torch.Size([512, 512])
# Generating image for seed 946 (946/1001) ...
# torch.Size([512, 512])
# Generating image for seed 947 (947/1001) ...
# torch.Size([512, 512])
# Generating image for seed 948 (948/1001) ...
# torch.Size([512, 512])
# Generating image for seed 949 (949/1001) ...
# torch.Size([512, 512])
# Generating image for seed 950 (950/1001) ...
# torch.Size([512, 512])
# Generating image for seed 951 (951/1001) ...
# torch.Size([512, 512])
# Generating image for seed 952 (952/1001) ...
# torch.Size([512, 512])
# Generating image for seed 953 (953/1001) ...
# torch.Size([512, 512])
# Generating image for seed 954 (954/1001) ...
# torch.Size([512, 512])
# Generating image for seed 955 (955/1001) ...
# torch.Size([512, 512])
# Generating image for seed 956 (956/1001) ...
# torch.Size([512, 512])
# Generating image for seed 957 (957/1001) ...
# torch.Size([512, 512])
# Generating image for seed 958 (958/1001) ...
# torch.Size([512, 512])
# Generating image for seed 959 (959/1001) ...
# torch.Size([512, 512])
# Generating image for seed 960 (960/1001) ...
# torch.Size([512, 512])
# Generating image for seed 961 (961/1001) ...
# torch.Size([512, 512])
# Generating image for seed 962 (962/1001) ...
# torch.Size([512, 512])
# Generating image for seed 963 (963/1001) ...
# torch.Size([512, 512])
# Generating image for seed 964 (964/1001) ...
# torch.Size([512, 512])
# Generating image for seed 965 (965/1001) ...
# torch.Size([512, 512])
# Generating image for seed 966 (966/1001) ...
# torch.Size([512, 512])
# Generating image for seed 967 (967/1001) ...
# torch.Size([512, 512])
# Generating image for seed 968 (968/1001) ...
# torch.Size([512, 512])
# Generating image for seed 969 (969/1001) ...
# torch.Size([512, 512])
# Generating image for seed 970 (970/1001) ...
# torch.Size([512, 512])
# Generating image for seed 971 (971/1001) ...
# torch.Size([512, 512])
# Generating image for seed 972 (972/1001) ...
# torch.Size([512, 512])
# Generating image for seed 973 (973/1001) ...
# torch.Size([512, 512])
# Generating image for seed 974 (974/1001) ...
# torch.Size([512, 512])
# Generating image for seed 975 (975/1001) ...
# torch.Size([512, 512])
# Generating image for seed 976 (976/1001) ...
# torch.Size([512, 512])
# Generating image for seed 977 (977/1001) ...
# torch.Size([512, 512])
# Generating image for seed 978 (978/1001) ...
# torch.Size([512, 512])
# Generating image for seed 979 (979/1001) ...
# torch.Size([512, 512])
# Generating image for seed 980 (980/1001) ...
# torch.Size([512, 512])
# Generating image for seed 981 (981/1001) ...
# torch.Size([512, 512])
# Generating image for seed 982 (982/1001) ...
# torch.Size([512, 512])
# Generating image for seed 983 (983/1001) ...
# torch.Size([512, 512])
# Generating image for seed 984 (984/1001) ...
# torch.Size([512, 512])
# Generating image for seed 985 (985/1001) ...
# torch.Size([512, 512])
# Generating image for seed 986 (986/1001) ...
# torch.Size([512, 512])
# Generating image for seed 987 (987/1001) ...
# torch.Size([512, 512])
# Generating image for seed 988 (988/1001) ...
# torch.Size([512, 512])
# Generating image for seed 989 (989/1001) ...
# torch.Size([512, 512])
# Generating image for seed 990 (990/1001) ...
# torch.Size([512, 512])
# Generating image for seed 991 (991/1001) ...
# torch.Size([512, 512])
# Generating image for seed 992 (992/1001) ...
# torch.Size([512, 512])
# Generating image for seed 993 (993/1001) ...
# torch.Size([512, 512])
# Generating image for seed 994 (994/1001) ...
# torch.Size([512, 512])
# Generating image for seed 995 (995/1001) ...
# torch.Size([512, 512])
# Generating image for seed 996 (996/1001) ...
# torch.Size([512, 512])
# Generating image for seed 997 (997/1001) ...
# torch.Size([512, 512])
# Generating image for seed 998 (998/1001) ...
# torch.Size([512, 512])
# Generating image for seed 999 (999/1001) ...
# torch.Size([512, 512])
# Generating image for seed 1000 (1000/1001) ...
# torch.Size([512, 512])

# %% [markdown]
# ## Calc_metrics

# %%
# !python calc_metrics.py --metrics=fid50k_full --data=dataset_floder.zip --mirror=1 --network= path to netwrok
# Out:
# Loading network from "./training-runs/00000-sunh-auto2-kimg1000/network-snapshot-001000.pkl"...
# Dataset options:
# {
#   "class_name": "training.dataset.ImageFolderDataset",
#   "path": "./datasets/sunh.zip",
#   "resolution": 512,
#   "use_labels": false,
#   "xflip": true
# }
# Launching processes...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Generator             Parameters  Buffers  Output shape        Datatype
# ---                   ---         ---      ---                 ---
# mapping.fc0           262656      -        [1, 512]            float32
# mapping.fc1           262656      -        [1, 512]            float32
# mapping               -           512      [1, 16, 512]        float32
# synthesis.b4.conv1    2622465     32       [1, 512, 4, 4]      float32
# synthesis.b4.torgb    263169      -        [1, 1, 4, 4]        float32
# synthesis.b4:0        8192        16       [1, 512, 4, 4]      float32
# synthesis.b4:1        -           -        [1, 512, 4, 4]      float32
# synthesis.b8.conv0    2622465     80       [1, 512, 8, 8]      float32
# synthesis.b8.conv1    2622465     80       [1, 512, 8, 8]      float32
# synthesis.b8.torgb    263169      -        [1, 1, 8, 8]        float32
# synthesis.b8:0        -           16       [1, 512, 8, 8]      float32
# synthesis.b8:1        -           -        [1, 512, 8, 8]      float32
# synthesis.b16.conv0   2622465     272      [1, 512, 16, 16]    float32
# synthesis.b16.conv1   2622465     272      [1, 512, 16, 16]    float32
# synthesis.b16.torgb   263169      -        [1, 1, 16, 16]      float32
# synthesis.b16:0       -           16       [1, 512, 16, 16]    float32
# synthesis.b16:1       -           -        [1, 512, 16, 16]    float32
# synthesis.b32.conv0   2622465     1040     [1, 512, 32, 32]    float32
# synthesis.b32.conv1   2622465     1040     [1, 512, 32, 32]    float32
# synthesis.b32.torgb   263169      -        [1, 1, 32, 32]      float32
# synthesis.b32:0       -           16       [1, 512, 32, 32]    float32
# synthesis.b32:1       -           -        [1, 512, 32, 32]    float32
# synthesis.b64.conv0   2622465     4112     [1, 512, 64, 64]    float16
# synthesis.b64.conv1   2622465     4112     [1, 512, 64, 64]    float16
# synthesis.b64.torgb   263169      -        [1, 1, 64, 64]      float16
# synthesis.b64:0       -           16       [1, 512, 64, 64]    float16
# synthesis.b64:1       -           -        [1, 512, 64, 64]    float32
# synthesis.b128.conv0  1442561     16400    [1, 256, 128, 128]  float16
# synthesis.b128.conv1  721409      16400    [1, 256, 128, 128]  float16
# synthesis.b128.torgb  131585      -        [1, 1, 128, 128]    float16
# synthesis.b128:0      -           16       [1, 256, 128, 128]  float16
# synthesis.b128:1      -           -        [1, 256, 128, 128]  float32
# synthesis.b256.conv0  426369      65552    [1, 128, 256, 256]  float16
# synthesis.b256.conv1  213249      65552    [1, 128, 256, 256]  float16
# synthesis.b256.torgb  65793       -        [1, 1, 256, 256]    float16
# synthesis.b256:0      -           16       [1, 128, 256, 256]  float16
# synthesis.b256:1      -           -        [1, 128, 256, 256]  float32
# synthesis.b512.conv0  139457      262160   [1, 64, 512, 512]   float16
# synthesis.b512.conv1  69761       262160   [1, 64, 512, 512]   float16
# synthesis.b512.torgb  32897       -        [1, 1, 512, 512]    float16
# synthesis.b512:0      -           16       [1, 64, 512, 512]   float16
# synthesis.b512:1      -           -        [1, 64, 512, 512]   float32
# ---                   ---         ---      ---                 ---
# Total                 28694615    699904   -                   -
#
# Calculating fid50k_full...
# dataset features    items 1024    time 9s           ms/item 8.36
# dataset features    items 2048    time 12s          ms/item 3.45
# dataset features    items 3072    time 15s          ms/item 3.22
# dataset features    items 4096    time 19s          ms/item 3.29
# dataset features    items 5120    time 22s          ms/item 3.27
# dataset features    items 6144    time 26s          ms/item 3.38
# dataset features    items 7168    time 29s          ms/item 3.24
# dataset features    items 8192    time 32s          ms/item 3.29
# dataset features    items 9216    time 36s          ms/item 3.23
# dataset features    items 10240   time 39s          ms/item 3.22
# dataset features    items 10809   time 42s          ms/item 5.14
# generator features  items 1024    time 23s          ms/item 22.93
# generator features  items 2048    time 45s          ms/item 20.75
# generator features  items 3072    time 1m 06s       ms/item 20.93
# generator features  items 4096    time 1m 27s       ms/item 20.81
# generator features  items 5120    time 1m 48s       ms/item 20.07
# generator features  items 6144    time 2m 10s       ms/item 21.09
# generator features  items 7168    time 2m 31s       ms/item 21.14
# generator features  items 8192    time 2m 53s       ms/item 20.89
# generator features  items 9216    time 3m 14s       ms/item 20.80
# generator features  items 10240   time 3m 35s       ms/item 20.93
# generator features  items 11264   time 3m 57s       ms/item 20.80
# generator features  items 12288   time 4m 18s       ms/item 21.03
# generator features  items 13312   time 4m 40s       ms/item 20.91
# generator features  items 14336   time 5m 01s       ms/item 20.81
# generator features  items 15360   time 5m 22s       ms/item 20.92
# generator features  items 16384   time 5m 44s       ms/item 20.88
# generator features  items 17408   time 6m 05s       ms/item 20.98
# generator features  items 18432   time 6m 26s       ms/item 20.30
# generator features  items 19456   time 6m 48s       ms/item 21.06
# generator features  items 20480   time 7m 09s       ms/item 20.95
# generator features  items 21504   time 7m 30s       ms/item 20.78
# generator features  items 22528   time 7m 52s       ms/item 21.06
# generator features  items 23552   time 8m 13s       ms/item 20.82
# generator features  items 24576   time 8m 35s       ms/item 20.96
# generator features  items 25600   time 8m 56s       ms/item 20.96
# generator features  items 26624   time 9m 17s       ms/item 20.77
# generator features  items 27648   time 9m 39s       ms/item 21.19
# generator features  items 28672   time 10m 01s      ms/item 21.11
# generator features  items 29696   time 10m 22s      ms/item 21.06
# generator features  items 30720   time 10m 43s      ms/item 20.10
# generator features  items 31744   time 11m 04s      ms/item 20.97
# generator features  items 32768   time 11m 26s      ms/item 20.76
# generator features  items 33792   time 11m 47s      ms/item 21.00
# generator features  items 34816   time 12m 09s      ms/item 20.94
# generator features  items 35840   time 12m 30s      ms/item 20.81
# generator features  items 36864   time 12m 51s      ms/item 20.97
# generator features  items 37888   time 13m 13s      ms/item 20.83
# generator features  items 38912   time 13m 34s      ms/item 20.91
# generator features  items 39936   time 13m 56s      ms/item 21.11
# generator features  items 40960   time 14m 17s      ms/item 20.96
# generator features  items 41984   time 14m 39s      ms/item 21.21
# generator features  items 43008   time 14m 59s      ms/item 20.15
# generator features  items 44032   time 15m 21s      ms/item 21.22
# generator features  items 45056   time 15m 43s      ms/item 20.95
# generator features  items 46080   time 16m 04s      ms/item 20.99
# generator features  items 47104   time 16m 25s      ms/item 20.84
# generator features  items 48128   time 16m 47s      ms/item 20.93
# generator features  items 49152   time 17m 08s      ms/item 20.96
# generator features  items 50000   time 17m 27s      ms/item 22.09
# {"results": {"fid50k_full": 3.1131835824862097}, "metric": "fid50k_full", "total_time": 1096.7636423110962, "total_time_str": "18m 17s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-001000.pkl", "timestamp": 1612753167.062439}
#
# Exiting...

# %% [markdown]
# # Stlyle mixing

# %%
# !python style_mixing_gray.py --outdir=stylemix --rows=1,6,10,11,13,22,25,34 --cols=37,39,38,35, 29 --network= path to netwrok
# Out:
# Loading networks from "./training-runs/00000-sunh-auto2-kimg1000/network-snapshot-000800.pkl"...
# Generating W vectors...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Generating images...
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating style-mixed images...
# Saving images...
# Saving image grid...

# %% [markdown]
# # Projecter
#
# Projecting images to latent space

# %%
# !python projector_gray.py --outdir=out --target=~/mytargetimg.png --network= path to netwrok

# %% [markdown]
# # Make zip file

# %%
import os
import zipfile

def zipdir(path, ziph):
    # ziph is zipfile handle
    for root, dirs, files in os.walk(path):
        for file in files:
            ziph.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), os.path.join(path, '..')))

if __name__ == '__main__':
    zipf = zipfile.ZipFile('0331_class4_generated.zip', 'w', zipfile.ZIP_DEFLATED)
    zipdir('./out0330', zipf)
    zipf.close()
